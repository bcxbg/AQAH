# %%
import sys
from nltk.stem import *
import nltk
import json
from pattern.en import singularize
import argparse
import tqdm
import time
import random
lemma = nltk.wordnet.WordNetLemmatizer()

def combine_coco_captions(annotation_path):

    # if not os.path.exists('%s/captions_%s2014.json' %(annotation_path, 'val')):
    #     raise Exception("Please download MSCOCO caption annotations for val set")
    # if not os.path.exists('%s/captions_%s2014.json' %(annotation_path, 'train')):
    #     raise Exception("Please download MSCOCO caption annotations for train set")
    with open(annotation_path) as file:
        all_caps = json.load(file)
    return all_caps 


def combine_coco_instances(annotation_path):

    # if not os.path.exists('%s/instances_%s2014.json' %(annotation_path, 'val')):
    #     raise Exception("Please download MSCOCO instance annotations for val set")
    # if not os.path.exists('%s/instances_%s2014.json' %(annotation_path, 'train')):
    #     raise Exception("Please download MSCOCO instance annotations for train set")

    # val_instances = json.load(open('%s/instances_%s2014.json' %(annotation_path, 'val')))
    # train_instances = json.load(open('%s/instances_%s2014.json' %(annotation_path, 'train')))
    # all_instances = {'info': train_instances['info'],
    #                  'licenses': train_instances['licenses'],
    #                  'type': train_instances['licenses'],
    #                  'categories': train_instances['categories'],
    #                  'images': train_instances['images'] + val_instances['images'],
    #                  'annotations': val_instances['annotations'] + train_instances['annotations']}
    # train_instances.extend(val_instances)
    # all_instances = train_instances
    with open(annotation_path) as file:
        all_instances = json.load(file)
    return all_instances 

class CHAIR(object):

    def __init__(self, imids):

        self.imid_to_objects = {imid: [] for imid in imids}
        synonyms = open('/data/dtt/project/LLaVA-main/hallucination/code/annotations/synonyms.txt').readlines()
        synonyms = [s.strip().split(', ') for s in synonyms]
        self.synomyms = {}
        for s_line_ls in synonyms:
            for single_s in s_line_ls:
                self.synomyms[single_s] = s_line_ls[0]
        #read in synonyms
        # synonym_path = ""
        # synonyms = open('data/synonyms.txt').readlines()
        # synonyms = [s.strip().split(', ') for s in synonyms]
        self.mscoco_objects = [] #mscoco objects and *all* synonyms
        self.inverse_synonym_dict = {}
        self.mscoco_objects_total = []
        self.inverse_synonym_dict_total = {}
        synonym_path = ""
        synonyms = open('/data/dtt/project/LLaVA-main/hallucination/code/annotations/synonyms.txt').readlines()
        synonyms = [s.strip().split(', ') for s in synonyms]
        for synonym in synonyms:
            self.mscoco_objects_total.extend(synonym) #["all names"]
            for s in synonym:
                self.inverse_synonym_dict_total[s] = synonym[0]

        #read in synonyms
        synonym_path = "/data/dtt/project/LLaVA-main/hallucination/code/annotations/object_synsets.json"
        with open(synonym_path) as file:
            synonyms = json.load(file)
        for object_key,object_value in synonyms.items():
            self.mscoco_objects.append(object_key)
            self.inverse_synonym_dict[object_key] = object_value.split('.')[0]
            #"black hole": "hole.n.01"

        #Some hard coded rules for implementing CHAIR metrics on MSCOCO
        
        # #common 'double words' in MSCOCO that should be treated as a single word
        # coco_double_words = ['motor bike', 'motor cycle', 'air plane', 'traffic light', 'street light', 'traffic signal', 'stop light', 'fire hydrant', 'stop sign', 'parking meter', 'suit case', 'sports ball', 'baseball bat', 'baseball glove', 'tennis racket', 'wine glass', 'hot dog', 'cell phone', 'mobile phone', 'teddy bear', 'hair drier', 'potted plant', 'bow tie', 'laptop computer', 'stove top oven', 'hot dog', 'teddy bear', 'home plate', 'train track']
        
        # #Hard code some rules for special cases in MSCOCO
        # #qualifiers like 'baby' or 'adult' animal will lead to a false fire for the MSCOCO object 'person'.  'baby bird' --> 'bird'.
        # animal_words = ['bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'animal', 'cub']
        # #qualifiers like 'passenger' vehicle will lead to a false fire for the MSCOCO object 'person'.  'passenger jet' --> 'jet'.
        # vehicle_words = ['jet', 'train']
        
        # #double_word_dict will map double words to the word they should be treated as in our analysis
        
        # self.double_word_dict = {}
        # for double_word in coco_double_words:
        #     self.double_word_dict[double_word] = double_word
        # for animal_word in animal_words:
        #     self.double_word_dict['baby %s' %animal_word] = animal_word
        #     self.double_word_dict['adult %s' %animal_word] = animal_word
        # for vehicle_word in vehicle_words:
        #     self.double_word_dict['passenger %s' %vehicle_word] = vehicle_word
        # self.double_word_dict['bow tie'] = 'tie'
        # self.double_word_dict['toilet seat'] = 'toilet'
        # self.double_word_dict['wine glas'] = 'wine glass'

    def _load_generated_captions_into_evaluator(self, cap_file):

        '''
        Meant to save time so imid_to_objects does not always need to be recomputed.
        '''
        #Read in captions        
        self.caps, imids = load_generated_captions(cap_file)

        assert imids == set(self.imid_to_objects.keys())

    def caption_to_words(self, caption):
    
        '''
        Input: caption
        Output: MSCOCO words in the caption
        '''
    
        #standard preprocessing
        if caption == None:
            return [],[],[],[]
        words = nltk.word_tokenize(caption.lower())
        words = [singularize(w) for w in words]
        words = list(set(words))
        raw_words = words
        #replace double words
        #i = 0
        # double_words = []
        # idxs = []
        # while i < len(words):
        #    idxs.append(i) 
        #    double_word = ' '.join(words[i:i+2])
        #    if double_word in self.double_word_dict: 
        #        double_words.append(self.double_word_dict[double_word])
        #        i += 2
        #    else:
        #        double_words.append(words[i])
        #        i += 1
        # words = double_words

        
        #toilet seat is not chair (sentences like "the seat of the toilet" will fire for "chair" if we do not include this line)
        #if ('toilet' in words) & ('seat' in words): words = [word for word in words if word != 'seat']
    
        #get synonyms for all words in the caption
        idxs = [i for i in range(len(words))]
        idxs = [idxs[idx] for idx, word in enumerate(words) \
                if word in set(self.mscoco_objects)]
        words = [word for word in words if word in set(self.mscoco_objects)]
        node_words = []
        for word in words:
            node_words.append(self.inverse_synonym_dict[word])
        #return all the MSCOCO objects in the caption
        return words, node_words, idxs,raw_words


    def caption_to_words_total(self,caption):
        if caption == None:
            return [],[],[],[]
        words = nltk.word_tokenize(caption.lower())
        words = [singularize(w) for w in words]
        words = list(set(words))
        raw_words = words

        idxs = [i for i in range(len(words))]
        idxs = [idxs[idx] for idx, word in enumerate(words) \
                if word in set(self.mscoco_objects_total)]
        words = [word for word in words if word in set(self.mscoco_objects_total)]
        node_words = []
        for word in words:
            node_words.append(self.inverse_synonym_dict_total[word])
        return words, node_words, idxs,raw_words
    def get_annotations_from_segments(self,object_json_path):
        '''
        Add objects taken from MSCOCO segmentation masks
        '''

        # coco_segments = combine_coco_instances(self.coco_path)
        # segment_annotations = coco_segments['annotations']

        # #make dict linking object name to ids
        # id_to_name = {} #dict with id to synsets 
        # for cat in coco_segments['categories']:
        #     id_to_name[cat['id']] = cat['name']
        # #类别的id和类别的name之间的对应
        
        # for i, annotation in enumerate(segment_annotations):
        #     sys.stdout.write("\rGetting annotations for %d/%d segmentation masks" 
        #                       %(i, len(segment_annotations)))
        #     imid = annotation['image_id']
        #     if imid in self.imid_to_objects:
        #         node_word = self.inverse_synonym_dict[id_to_name[annotation['category_id']]]
        #         self.imid_to_objects[imid].append(node_word)
        # print ("\n")
        # for imid in self.imid_to_objects:
        #     self.imid_to_objects[imid] = set(self.imid_to_objects[imid])


        # #return self.imid_to_objects 
        # #img_id:node_word

        coco_segment = combine_coco_instances(object_json_path) #list
        #import ipdb;ipdb.set_trace()
        for i in tqdm.tqdm(range(len(coco_segment)),colour = 'blue'):
            temp_object = coco_segment[i] # dict
            img_id = temp_object['image_id']
            object_segment = temp_object['objects'] #list  length == number of object
            if img_id in self.imid_to_objects:
                
                for j in range(len(object_segment)):
                    object_synsets_name = object_segment[j]['synsets']
                    if object_synsets_name != []:
                        object_synsets_name = object_synsets_name[0] #list[-1]
                        object_synsets_name = object_synsets_name.split('.')[0]
                        if object_synsets_name in self.synomyms:
                            object_synsets_name = self.synomyms[object_synsets_name]
                        self.imid_to_objects[img_id].append(object_synsets_name)
        for img_id in self.imid_to_objects:
            self.imid_to_objects[img_id] = set(self.imid_to_objects[img_id])
        #import ipdb;ipdb.set_trace()
    
    def get_annotations_from_captions(self,question_answer_path):
        '''
        Add objects taken from MSCOCO ground truth captions 
        '''

        # coco_caps = combine_coco_captions(question_answer_path)
        # caption_annotations = coco_caps['annotations']

        # for i, annotation in enumerate(caption_annotations):
        #     sys.stdout.write('\rGetting annotations for %d/%d ground truth captions' 
        #                       %(i, len(coco_caps['annotations'])))
        #     imid = annotation['image_id']
        #     if imid in self.imid_to_objects:
        #         _, node_words, _, _ = self.caption_to_words(annotation['caption'])
        #         self.imid_to_objects[imid].update(node_words)
        # print ("\n")

        # for imid in self.imid_to_objects:
        #     self.imid_to_objects[imid] = set(self.imid_to_objects[imid])

        #return self.imid_to_objects
        #img_id node_word
        

        coco_caps = combine_coco_captions(question_answer_path)
        for i in tqdm.tqdm(range(len(coco_caps)),colour = 'green'):
            temp_question = coco_caps[i]#dict
            for j in range(len(temp_question['qas'])):
                img_id = temp_question['qas'][j]['image_id']
                
                if img_id in self.imid_to_objects:
                    single_caption = temp_question['qas'][j]['question']
                    if img_id == 2335234:
                        print("single_caption:{}".format(single_caption))
                    words, node_words, _,_=self.caption_to_words_total(single_caption)
                    for node_word in node_words:
                        if node_word in self.synomyms:
                            node_word = self.synomyms[node_word]
                        self.imid_to_objects[img_id].add(node_word)
                        
        for image_id in self.imid_to_objects:
            self.imid_to_objects[image_id] = set(self.imid_to_objects[image_id])
        #import ipdb;ipdb.set_trace()

    def get_annotations(self):

        '''
        Get annotations from both segmentation and captions.  Need both annotation types for CHAIR metric.
        '''

        self.get_annotations_from_segments("/data/dtt/project/LLaVA-main/hallucination/code/annotations/objects.json") 
        self.get_annotations_from_captions("/data/dtt/project/LLaVA-main/hallucination/code/annotations/new_qa.json") 

    def compute_chair(self, cap_file):
    
        '''
        Given ground truth objects and generated captions, determine which sentences have hallucinated words.
        '''
    
        self._load_generated_captions_into_evaluator(cap_file) #generate_caption_file

        imid_to_objects = self.imid_to_objects
        caps = self.caps #caps is a list
 
        num_caps = 0.
        num_hallucinated_caps = 0.
        hallucinated_word_count = 0.
        coco_word_count = 0.

        output = {'sentences': []} 
    
        for i in tqdm.tqdm(range(len(caps)),colour = 'red'):
            cap_eval = caps[i]
            cap = cap_eval['caption']
            imid = cap_eval['image_id']

            #get all words in the caption, as well as corresponding node word
            words, node_words, idxs,raw_words = self.caption_to_words_total(cap) #single caption 

            gt_objects = imid_to_objects[imid]
            cap_dict = {'image_id': cap_eval['image_id'], 
                        'caption': cap,
                        'mscoco_hallucinated_words': [],
                        'mscoco_gt_words': list(gt_objects),
                        'mscoco_generated_words': list(node_words),
                        'hallucination_idxs': [], 
                        'words': raw_words 
                        }
   
            cap_dict['metrics'] = {'Bleu_1': 0,
                                   'Bleu_2': 0,
                                   'Bleu_3': 0,
                                   'Bleu_4': 0,
                                   'METEOR': 0,
                                   'CIDEr': 0,
                                   'SPICE': 0,
                                   'ROUGE_L': 0,
                                   'CHAIRs': 0,
                                   'CHAIRi': 0}
 
            #count hallucinated words
            coco_word_count += len(node_words) #生成的caption里面存在的object个数。 
            hallucinated = False
            #print('gt_objects:{}'.format(gt_objects))
            #print("words:{}".format(words))
            print("cap:{}".format(cap))
            for word, node_word, idx in zip(words, node_words, idxs): #words是一个list
                if node_word in self.synomyms:
                    node_word = self.synomyms[node_word]
                if node_word in gt_objects:
                    #print("true node_word:{}".format(node_word))
                    pass
                if node_word not in gt_objects:
                    print("negetive node_word:{}".format(node_word))
                    #print("negetive word:{}".format(word))
                    hallucinated_word_count += 1 
                    cap_dict['mscoco_hallucinated_words'].append((word, node_word))
                    cap_dict['hallucination_idxs'].append(idx)
                    hallucinated = True      
    
            #count hallucinated caps
            num_caps += 1
            if hallucinated:
               num_hallucinated_caps += 1
    
            cap_dict['metrics']['CHAIRs'] = int(hallucinated)
            cap_dict['metrics']['CHAIRi'] = 0.
            if len(words) > 0:
                cap_dict['metrics']['CHAIRi'] = len(cap_dict['mscoco_hallucinated_words'])/float(len(words))
            #time.sleep(2)
            output['sentences'].append(cap_dict)
 
        chair_s = (num_hallucinated_caps/num_caps)
        chair_i = (hallucinated_word_count/coco_word_count)
    
        output['overall_metrics'] = {'Bleu_1': 0,
                                     'Bleu_2': 0,
                                     'Bleu_3': 0,
                                     'Bleu_4': 0,
                                     'METEOR': 0,
                                     'CIDEr': 0,
                                     'SPICE': 0,
                                     'ROUGE_L': 0,
                                     'CHAIRs': chair_s,
                                     'CHAIRi': chair_i}
    
        return output 

def load_generated_captions(cap_file,top_beam=True):
    #Read in captions        
    #cap_file [{'caption':,'image_id':},{}]
    
    #caps_data = json.load(open(cap_file))
    #caps = caps_data['caption_image_id']
    #imids = set([cap['image_id'] for cap in caps])
    #
    #    try:
    #        caps = caps['imgToEval'].values()
    #        imids = set([cap['image_id'] for cap in caps])
    #    except:
    #        raise Exception("Expect caption file to consist of a dectionary with sentences correspdonding to the key 'imgToEval'")
    
    single_qustion_dict = json.load(open(cap_file))
    image_name_ls = []
    image_value_ls = []
    count = 0
    for image_name,image_value in single_qustion_dict.items():
        image_name_ls.append(image_name)
        image_value_ls.append(image_value)
    caps = []
    for idx in tqdm.tqdm(range(len(image_value_ls))):
        image_name = image_name_ls[idx]
        image_value = image_value_ls[idx]
        
        # with open(file = "test_image_name.txt",encoding='utf-8',mode = 'a+') as file:
        #     file.write(str(image_name)+'\n')
        if type(image_value) == list:
            continue
        top_k_list = image_value["top_k_text"]
        beam_list = image_value['beam_text:']
        temp_idx = -1
        temp_top_k_len = 128
        my_list = [0, 1, 2, 3]
        random_element = random.choice(my_list)
        if top_k_list == None or beam_list == None:
            continue
        for i in range(len(top_k_list)):
            if len(top_k_list[i]) < temp_top_k_len:
                temp_idx = i
                temp_top_k_len = len(top_k_list[i])
        rs_top_k = top_k_list[temp_idx] if temp_idx != -1 else None
        rs_top_k = top_k_list[random_element]
        temp_idx = -1
        temp_beam_len = 128
        my_list = [0, 1]
        random_element = random.choice(my_list)
        for i in range(len(beam_list)):
            if len(beam_list[i]) < temp_beam_len:
                temp_idx = i
                temp_beam_len = len(beam_list[i])
        rs_beam = beam_list[temp_idx] if temp_idx != -1 else None
        rs_beam = beam_list[random_element]
        if top_beam:
            caps.append({'caption':rs_top_k,'image_id':int(image_name[:-4])})
        else:
            caps.append({'caption':rs_beam,'image_id':int(image_name[:-4])})
        #caps.append({'caption':rs_top_k,'image_id':int(image_name[:-4])})
        #caps.append({'caption':rs_beam,'image_id':int(image_name[:-4])})
    imids = set([cap['image_id'] for cap in caps])
    return caps, imids

def save_hallucinated_words(cap_file, cap_dict): 
    tag = cap_file.split('/')[-1] 
    with open('/data/dtt/project/LLaVA-main/hallucination/code/output/hallucinated_words_%s' %tag, 'a+') as f:
        json.dump(cap_dict, f)

def print_metrics(hallucination_cap_dict, quiet=False):
    sentence_metrics = hallucination_cap_dict['overall_metrics']
    metric_string = "%0.01f\t%0.01f\t%0.01f\t%0.01f\t%0.01f" %(
                                                  sentence_metrics['SPICE']*100,
                                                  sentence_metrics['METEOR']*100,
                                                  sentence_metrics['CIDEr']*100,
                                                  sentence_metrics['CHAIRs']*100,
                                                  sentence_metrics['CHAIRi']*100)

    if not quiet:
        print ("SPICE\tMETEOR\tCIDEr\tCHAIRs\tCHAIRi")
        print (metric_string)

    else:
        return metric_string
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/pattern/text/en/wordnet/__init__.py:57
#      56 try:
# ---> 57     nltk.data.find("corpora/" + token)
#      58 except LookupError:
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - '/home/dtt2/nltk_data'
#     - '/home/shengfang/miniconda3/envs/torch/nltk_data'
#     - '/home/shengfang/miniconda3/envs/torch/share/nltk_data'
#     - '/home/shengfang/miniconda3/envs/torch/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 import nltk
#       4 import json
# ----> 5 from pattern.en import singularize
#       6 import argparse
#       7 import tqdm
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/pattern/text/en/__init__.py:79
#      73 from pattern.text.en.modality import (
#      74     mood, INDICATIVE, IMPERATIVE, CONDITIONAL, SUBJUNCTIVE,
#      75     modality, uncertain, EPISTEMIC,
#      76     negated
#      77 )
#      78 # Import all submodules.
# ---> 79 from pattern.text.en import inflect
#      80 from pattern.text.en import wordnet
#      81 from pattern.text.en import wordlist
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/pattern/text/en/__init__.py:80
#      78 # Import all submodules.
#      79 from pattern.text.en import inflect
# ---> 80 from pattern.text.en import wordnet
#      81 from pattern.text.en import wordlist
#      83 sys.path.pop(0)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/pattern/text/en/wordnet/__init__.py:60
#      58 except LookupError:
#      59     try:
# ---> 60         nltk.download(token, quiet = True, raise_on_error = True)
#      61     except ValueError:
#      62         # Sometimes there are problems with the default index.xml URL. Then we will try this...
#      63         from nltk.downloader import Downloader as NLTKDownloader
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/downloader.py:777, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     768 def show(s, prefix2=""):
#     769     print_to(
#     770         textwrap.fill(
#     771             s,
#    (...)
#     774         )
#     775     )
# --> 777 for msg in self.incr_download(info_or_id, download_dir, force):
#     778     # Error messages
#     779     if isinstance(msg, ErrorMessage):
#     780         show(msg.message)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/downloader.py:629, in Downloader.incr_download(self, info_or_id, download_dir, force)
#     627 # Look up the requested collection or package.
#     628 try:
# --> 629     info = self._info_or_id(info_or_id)
#     630 except (OSError, ValueError) as e:
#     631     yield ErrorMessage(None, f"Error loading {info_or_id}: {e}")
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/downloader.py:603, in Downloader._info_or_id(self, info_or_id)
#     601 def _info_or_id(self, info_or_id):
#     602     if isinstance(info_or_id, str):
# --> 603         return self.info(info_or_id)
#     604     else:
#     605         return info_or_id
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/downloader.py:1009, in Downloader.info(self, id)
#    1006 def info(self, id):
#    1007     """Return the ``Package`` or ``Collection`` record for the
#    1008     given item."""
# -> 1009     self._update_index()
#    1010     if id in self._packages:
#    1011         return self._packages[id]
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/site-packages/nltk/downloader.py:952, in Downloader._update_index(self, url)
#     948 self._url = url or self._url
#     950 # Download the index file.
#     951 self._index = nltk.internals.ElementWrapper(
# --> 952     ElementTree.parse(urlopen(self._url)).getroot()
#     953 )
#     954 self._index_timestamp = time.time()
#     956 # Build a dictionary of packages.
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:1360, in HTTPSHandler.https_open(self, req)
#    1359 def https_open(self, req):
# -> 1360     return self.do_open(http.client.HTTPSConnection, req,
#    1361         context=self._context, check_hostname=self._check_hostname)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/urllib/request.py:1317, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1315 try:
#    1316     try:
# -> 1317         h.request(req.get_method(), req.selector, req.data, headers,
#    1318                   encode_chunked=req.has_header('Transfer-encoding'))
#    1319     except OSError as err: # timeout error
#    1320         raise URLError(err)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:1230, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1227 def request(self, method, url, body=None, headers={}, *,
#    1228             encode_chunked=False):
#    1229     """Send a complete request to the server."""
# -> 1230     self._send_request(method, url, body, headers, encode_chunked)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:1276, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1272 if isinstance(body, str):
#    1273     # RFC 2616 Section 3.7.1 says that text default has a
#    1274     # default charset of iso-8859-1.
#    1275     body = _encode(body, 'body')
# -> 1276 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:1225, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1223 else:
#    1224     raise CannotSendHeader()
# -> 1225 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:1004, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1002 msg = b"\r\n".join(self._buffer)
#    1003 del self._buffer[:]
# -> 1004 self.send(msg)
#    1006 if message_body is not None:
#    1007
#    1008     # create a consistent interface to message_body
#    1009     if hasattr(message_body, 'read'):
#    1010         # Let file-like take precedence over byte-like.  This
#    1011         # is needed to allow the current position of mmap'ed
#    1012         # files to be taken into account.
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:944, in HTTPConnection.send(self, data)
#     942 if self.sock is None:
#     943     if self.auto_open:
# --> 944         self.connect()
#     945     else:
#     946         raise NotConnected()
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:1392, in HTTPSConnection.connect(self)
#    1389 def connect(self):
#    1390     "Connect to a host on a given (SSL) port."
# -> 1392     super().connect()
#    1394     if self._tunnel_host:
#    1395         server_hostname = self._tunnel_host
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/http/client.py:915, in HTTPConnection.connect(self)
#     913 def connect(self):
#     914     """Connect to the host and port specified in __init__."""
# --> 915     self.sock = self._create_connection(
#     916         (self.host,self.port), self.timeout, self.source_address)
#     917     self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     919     if self._tunnel_host:
#
# File /home/shengfang/miniconda3/envs/torch/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     794 if source_address:
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#     798 err = None
#
# KeyboardInterrupt:

# %%
cap_file = "/data/dtt/project/LLaVA-main/hallucination/code/original_details/1000_captions.json"
#cap_file = "C:/Users/hutter_sadan/Desktop/UCAS/blip2/data/VG_BLIP2_500_6.json"
_, imids = load_generated_captions(cap_file,True)
print(imids) 
evaluator = CHAIR(imids) 
evaluator.get_annotations()
print(len(imids))
cap_dict = evaluator.compute_chair(cap_file)     
print_metrics(cap_dict)
#save_hallucinated_words(args.cap_file, cap_dict)
# Out:
# 100%|██████████| 499/499 [00:00<00:00, 250054.68it/s]
# {2365441, 2412553, 2344971, 2357261, 2334734, 2351119, 2349075, 2416667, 2367520, 2316323, 2094, 2332720, 2353201, 2349105, 2379830, 2369602, 2361413, 61513, 2396236, 2365521, 2345047, 2336859, 2361437, 2318429, 2334815, 2355297, 2394217, 2359410, 2392180, 2377845, 2402423, 2336889, 2355322, 2332801, 2326662, 2367625, 2369674, 2347152, 2416784, 2338980, 2343083, 2412716, 2400432, 2379952, 2379960, 2322620, 190, 2400447, 2373826, 2375883, 2347213, 207, 2384079, 2406615, 2330845, 2373855, 2345189, 2394341, 2398439, 2392298, 2398446, 2355445, 2414850, 2359559, 2392331, 2377997, 2318614, 2404631, 2378006, 2398486, 2324762, 2335005, 2416934, 2347306, 2382124, 2349, 2320689, 2345270, 2410806, 2378041, 2332986, 2345277, 2318667, 2388317, 2400606, 2328928, 713057, 2361698, 2363755, 2361709, 2392431, 2369904, 2316658, 2374002, 2326905, 2406783, 4479, 2351487, 2341257, 2386314, 4494, 2400655, 4503, 2367895, 2363805, 2363806, 2341280, 2351526, 2363815, 2320815, 2367925, 2337205, 2345406, 2396607, 2400702, 2363844, 2388422, 2322889, 2415062, 2406871, 2404825, 2337248, 2339312, 2327027, 2343418, 2367997, 2339325, 2400767, 2335234, 515, 2382339, 2341381, 2394630, 2341383, 2335238, 2413073, 2318866, 498202, 559, 2339378, 2411065, 2337340, 2386496, 2335297, 2394694, 2347592, 2333257, 2316880, 2363985, 2345554, 2323027, 2351702, 2384473, 2388575, 2388576, 2343521, 2382435, 2378341, 2404968, 2370162, 2370170, 2316924, 2329213, 2691, 2415236, 2400899, 2392713, 2372237, 2370193, 2337427, 2400919, 2402972, 2337441, 2732, 2351792, 2394804, 2362040, 2405050, 2343611, 4798, 2382539, 2396878, 2370263, 2388701, 2380512, 2321123, 2360036, 2380515, 2415341, 2411252, 2398967, 2341626, 2319098, 2398971, 2325246, 2353920, 2360064, 775, 2355976, 2403083, 2390799, 2335505, 2409234, 2836, 2351894, 2331417, 2351899, 2370338, 2368293, 2317094, 2370357, 2370358, 2343737, 2358075, 4925, 2335554, 2384706, 2349912, 2351961, 713563, 2351965, 2407264, 2319202, 2341731, 2388841, 2341739, 2327404, 2351985, 2409331, 2415485, 2337661, 2343805, 906, 2370454, 2403224, 2319256, 2405280, 2329508, 2368424, 2319282, 713651, 2388924, 2356158, 2399167, 150468, 2327494, 2403271, 2407376, 2368469, 2325477, 2329585, 2343921, 2343928, 2384889, 2417657, 2362365, 2356231, 1160200, 2325513, 2411532, 1037, 2323470, 150541, 2360336, 2337809, 2337810, 2362384, 2376725, 1592350, 2393119, 2354215, 2417712, 2401329, 2399281, 2411573, 2376760, 2333757, 2384957, 2399296, 2401354, 2339929, 2350170, 1592412, 2344039, 2319463, 2387049, 1131, 2366571, 2344045, 2376815, 2356336, 2368623, 2378866, 713839, 2385014, 2366584, 2354301, 2331774, 2329726, 2337920, 2387077, 2409606, 2366607, 2321553, 2329748, 2397335, 2337946, 2403486, 2325665, 2337958, 2417831, 2329769, 2385076, 2415800, 2319549, 2405566, 2340034, 1220, 2383046, 2323663, 2376913, 2387155, 2395348, 2366682, 2409690, 2372833, 2399459, 2387173, 2327785, 2376942, 2385134, 2354430, 1282, 2411778, 2409749, 2401566, 2340128, 2381099, 2325806, 2399541, 1337, 2372924, 2417985, 2405698, 2356547, 2315591, 2407751, 2329931, 2358604, 2403662, 2399566, 2321744, 2350418, 2342232, 2336097, 2332006, 286057, 2385261, 2403697, 2372978, 2405747, 2389367, 2327929, 2381181, 2385278, 2352515, 2407812, 2329991, 2411918, 2330000, 2413990, 1592748, 2319790, 2338222, 2385330, 2416059, 2381245, 2403781, 2409926, 2391495, 2350539, 2395597, 2321869, 2385360, 2385363, 2383320, 3550, 2319844, 2383334, 2379246, 2416112, 2414065, 2336246, 2346490, 2340352, 2321922, 2405902, 2391575, 2416151, 2324000, 2350635, 2381358, 2360879, 2373168, 2399794, 2391615, 2340416, 1602, 2358853, 2350664, 2344526, 2391633, 2367061, 2403928, 2338399, 2416226, 1635, 2375266, 2408040, 2352750, 2365041, 2385536, 2373258, 2408079, 2315923, 2412183, 2381473, 2406050, 2395813, 2399920, 2410161, 2397875, 2410185, 2361036, 2320078, 2391761, 2410197, 2373334, 2361046, 2369245, 2410205, 2342628, 2385638, 2354919, 2414318, 2404080, 2361074, 2399988, 2397947, 2352896, 2340614, 2316039, 2373392, 2391826, 2 ...
# 100%|██████████| 108077/108077 [00:00<00:00, 1403760.00it/s]
# 100%|██████████| 396/396 [00:00<00:00, 385548.84it/s]
# 499
# 100%|██████████| 499/499 [00:00<00:00, 249043.04it/s]
#  34%|███▍      | 171/499 [00:00<00:00, 1709.94it/s]
# cap:white linens,
# cap:the ostrich is long and black with a white patch of skin
# cap:black poles and trees
# cap:tray has vegetables and meat on it
# cap:stone buildings, a green grassy field, a tower and towering trees
# cap:i see a stop light and a street sign near some trees
# cap:a pier in the water near the ocean
# cap:man is doing a skateboard trick
# cap:boy in tie
# negetive node_word:tie
# negetive node_word:person
# cap:Several spectators are on the tennis court
# cap:people in the picture are standing on the court watching
# cap:people are walking in the road
# negetive node_word:person
# cap:three men looking at the view
# cap:the room has curtains
# cap:airplane in the sky, with landing apron
# cap:man standing on the motorcycle
# cap:The player is playing tennis. His tennis racket is in front of him.
# negetive node_word:tennis racket
# negetive node_word:person
# cap:person is walking in snow
# cap:a teen is riding a skateboard
# cap:the man is wearing a black shirt
# cap:of a man and woman smiling together
# cap:four bronc riders in red jacket
# negetive node_word:person
# negetive node_word:horse
# cap:a snowboarder is riding down a snow covered slope
# cap:a person is performing a trick
# cap:man is wearing a black shirt
# cap:man playing tennis with a racket
# cap:the pier is in the water
# cap:people sitting at tables
# cap:a brown plate
# cap:the plane is blue and yellow
# negetive node_word:airplane
# cap:a man is eating a doughnut while sitting
# negetive node_word:donut
# cap:the trees next to the road
# cap:a boat with a man in it
# cap:sofa tan carpet, couch, chair
# cap:the people
# cap:man sitting next to large red case
# negetive node_word:person
# cap:the blue leash
# cap:man playing tennis
# cap:boy standing in a tennis court
# negetive node_word:person
# cap:there is a fireplace and a lamp
# cap:car driving at night
# cap:guy is on the surfboard
# cap:parasails flying over ocean
# cap:cars driving in the city
# cap:a dog walking on the road near a car
# cap:a bath tub and sink in a bathroom
# cap:the pork chop, broccoli, and wine
# cap:man is on a cell phone
# cap:elephants laying down
# negetive node_word:elephant
# cap:people standing on the podium
# cap:person is walking past
# cap:cubicle is messy and has many papers on it
# cap:a bathroom sink with towels in the middle of a shower
# negetive node_word:sink
# cap:a white teddy bear
# cap:several people sitting on a sofa in front of a laptop
# negetive node_word:laptop
# cap:a skateboarder is performing a trick on a pavement
# cap:tennis player on the tennis court
# cap:people in front of a banana tree
# cap:a bunch of players seated on some grassy area, with a team photo in the background
# cap:a baby bathtub is on a tv stand
# negetive node_word:tv
# negetive node_word:person
# cap:food
# cap:a woman is holding a tennis racquet
# cap:bears on shelves
# cap:giraffe in its cage
# negetive node_word:giraffe
# cap:person is skating
# cap:a rusty toilet with a dirty seat
# negetive node_word:toilet
# negetive node_word:chair
# cap:vase is filled with white flowers
# cap:two men in blue shirts
# cap:i
# cap:the large elephant
# cap:person is riding down a snow covered slope
# cap:the person is surfing
# cap:small airplane is flying by a mountain
# cap:bicycles in a row
# negetive node_word:bicycle
# cap:boy is lying down laying in bed
# negetive node_word:person
# negetive node_word:bed
# cap:elks in their natural habitat, in a grassy field with trees
# cap:man wearing blue and white shirt
# cap:the screen on the left laptop is blue
# cap:sheep on the ground
# cap:a group of people standing in front of an airplane
# cap:two buses at the end of a street
# cap:a conveyor belt is filling with donuts
# cap:the apartment's kitchen includes black and brown wood floors
# cap:woman in dress holding cell phone
# negetive node_word:cell phone
# cap:white plates
# cap:one duck is standing on grass
# cap:cattle standing at the back of the field
# cap:man is on the telephone
# negetive node_word:person
# negetive node_word:cell phone
# cap:Two birds standing next to a plate
# cap:person
# cap:The catcher's position is shown
# cap:blue jet plane
# cap:the ceiling of this train station
# negetive node_word:train
# cap:woman kneeling in front of waterfall
# cap:there are many trees
# cap:tree in background
# cap:three people standing around
# cap:The airliners tarmac is paved with snow
# cap:bus
# cap:on top of dessert is a cake
# cap:a round plate on a table
# cap:People are sitting around the table
# cap:a dog sitting
# cap:cars parked around the street stop sign
# negetive node_word:car
# cap:furniture style
# cap:girl with curly hair sitting down
# cap:two animals, one is standing
# cap:cars are going fast on the highway
# cap:women standing near two boys holding a frisbee
# negetive node_word:frisbee
# cap:white toilet with a seat that is up
# cap:man is standing
# cap:- the fireplace is on the floor - there is a tv on the side
# negetive node_word:tv
# cap:tall grass
# cap:train station
# negetive node_word:train
# cap:a group of kite flying people
# cap:a cat is sleeping on the lap top
# cap:many people are walking on a frozen pond
# cap:two white polar bears standing next to each other
# cap:children are watching a skateboarder
# cap:Two elephants stand near each other in an enclosure
# cap:man carrying an orange surfboard
# negetive node_word:person
# negetive node_word:orange
# negetive node_word:surfboard
# cap:a red plane in an airport
# cap:cypress trees
# cap:a brown rusted truck sits in snow beside a tan field
# negetive node_word:truck
# cap:a table with a laptop and paper
# cap:people are in the picture
# cap:two white wheeled carts on the sidewalk
# cap:of big ben, london skyline, a river and other cities
# cap:the laptop is on the ground, next to a mouse
# negetive node_word:laptop
# cap:person wearing a striped shirt
# negetive node_word:person
# cap:birds are in a sky
# cap:man wearing a shirt and jeans with a polo
# cap:the people inside the building
# negetive node_word:person
# cap:a green and yellow bus parked at a stop
# cap:people on scooters
# negetive node_word:motorcycle
# cap:woman holding book and bag
# negetive node_word:book
# cap:the bikes are blue
# cap:elephants
# cap:man skating
# negetive node_word:person
# cap:Dog is walking on a skateboard
# negetive node_word:skateboard
# negetive node_word:dog
# cap:desk with a desk lamp
# cap:the bathtub is in beige tiles
# cap:A couple of boys are laying on the grass
# cap:a baby is standing near a stainless steal refrigerator
# negetive node_word:person
# cap:the meter is green and metal
# cap:a slice of pizza is on a plate
# negetive node_word:pizza
# cap:computer, monitor, keyboard, and chair are on a desk
# cap:there are 2 jets flying above a tree
# cap:cat sitting on couch
# negetive node_word:couch
# cap:street
# cap:people with umbrellas, walking in the flooded street,
# cap:sign with chinese writing on it
# cap:children are sitting in a chair
# cap:two young girls with plates of pizza on the counter
# cap:the person is sitting on the motorcycle
# cap:the men are next to a truck
# cap:four people trying to catch a frisbee
# cap:The motorcycles are inside of the parking lot
# negetive node_word:motorcycle
# cap:giraffe looking out at the treetops
# cap:car passing by
# cap:a yellow and black vehicle is driving down a dirt road
# cap:young blond boy is eating donut
# negetive node_word:person
# cap:white house is large and has a long roof
# cap:living room is a living room with a wood floor and a large window
# cap:people in coats and hats walking on a sidewalk
# cap:people are walking near a red fire hydrant
# negetive node_word:fire hydrant
# cap:white toothbrush on black surface
# negetive node_word:toothbrush
# cap:big ben, a clock, and some other buildings
# negetive node_word:clock
# cap:glass of wine
# cap:a person is riding in this
# cap:three boys on grass
# cap:books are all lined up on the bookshelf
# cap:green leaves, radishes, carrots, broccoli
# negetive node_word:broccoli
# negetive node_word:carrot
# cap:man is a man
# cap:sign with a venice canal sign
# cap:the two men are holding a carved pumpkin
# negetive node_word:person
# cap:two dogs running
# cap:four pictures of some colorful and colorful birds in some trees
# cap:person is talking on cell phone
# negetive node_word:cell phone
# cap:person is wearing a long purple shirt
# cap:the black and white stripes on the zebra
# cap:two plates with a coffee and dessert
# cap:there is a computer
# negetive node_word:laptop
# cap:two red phone booths next to a wall
# cap:the green bus is parked in front of a black building
# cap:- skateboard
# cap:animals
# cap:there are people sitting in a park
# negetive node_word:person
# cap:picture cake with cat on top
# negetive node_word:cat
# negetive node_word:cake
# cap:a kite is in the air
# cap:woman wearing a hat
# cap:several people walk around
# cap:a skateboarder jumps over another skateboard
# cap:a man sits in a park
# cap:a baseball player is ready for the pitch
# cap:a cat is looking at carrots
# cap:a clock tower on a brick wall is next to benches
# cap:a motorcyclist and a building on the street
# cap:two cars and buses
# negetive node_word:car
# cap:a wooden boat on the shore
# cap:the buildings in the background
# cap:woman and child are laying in bed eating
# cap:three photographs of the apple, knife, and plate
# cap:building
# cap:A black dog is in the water
# cap:A train is coming down the tracks and people are waiting for it
# cap:man wearing black sweater
# cap:a car is parked
# cap:two zebras
# negetive node_word:zebra
# cap:the beds are white
# negetive node_word:bed
# cap:white doors on a door with a mirror in it
# cap:plane with wheels and landing gear up on the runway
# cap:there are many people riding in the buses in traffic
# cap:a white couch a red table
# negetive node_word:couch
# cap:on the plate are two bundt cakes
# cap:the dog is a white and black husky
# cap:white plate
# cap:the cat is holding a phone in its mouth with a cat's paw on the back
# negetive node_word:cell phone
# cap:street sign and red light
# cap:o l d n g t a table with fruit, salad, croissants and wine
# cap:a giraffe is standing
# cap:two gray monkeys
# cap:the room is filled with bottles
# negetive node_word:bottle
# cap:people standing in the open field
# cap:intersection with some signs
# cap:box shaped pizza
# cap:clock tower and street lights
# cap:there is a fence near the fire hydrant
# negetive node_word:fire hydrant
# cap:two trains parked on the tracks
# cap:a rocky area near
# cap:black and white picture of a fire hydrant
# negetive node_word:fire hydrant
# cap:large tarmac with airport in background
# cap:man is sitting near a christmas tree
# negetive node_word:person
# cap:a small clock tower in the background
# cap:person in the picture is sitting on a horse
# cap:line of red and white fighter jets
# cap:a woman is with a dog
# cap:the blue truck driving along
# cap:the skier is on a mountain
# cap:the wing of the plane
# cap:people are standing near some kids playing frisbee
# cap:the house was constructed of wood
# cap:two toilets, one on the ground
# negetive node_word:toilet
# cap:a person catching a frisbee
# cap:airplane is yellow
# negetive node_word:airplane
# cap:people riding bikes next to the road
# cap:train with two cars
# negetive node_word:car
# cap:the players in blue jerseys are on the ground
# negetive node_word:person
# cap:a view of a train
# cap:building is on concrete
# cap:shark
# cap:people on the campus
# cap:person is a woman
# cap:a pie is sitting on a platter
# cap:the train is red and black
# cap:man is skiing
# cap:a potted plant and pots of flowers
# cap:a teddy bear
# cap:a person stands in the foreground of frame, looking into elephant's trunks
# negetive node_word:person
# cap:dog on sand
# cap:there is a train coming in
# cap:person is windsurfing in the ocean
# cap:a woman is on a bed with a high heel
# cap:the bear is on a chair
# negetive node_word:chair
# negetive node_word:bear
# cap:a black hat
# cap:the airplane is black and red
# negetive node_word:airplane
# cap:the street signs are red
# cap:person is looking
# cap:a young male is performing a trick while a girl is standing
# cap:the plate is white
# cap:wine glasses sit on a table
# cap:horse
# cap:a silver van driving down the road
# cap:police officers wearing leather jackets, walking with signs
# cap:the cloudy sky
# cap:young man and young woman are looking at each other
# cap:the trees are tall
# cap:two yellow train engines traveling down the tracks
# cap:men in blue and white are spraying a fire hydrant
# negetive node_word:fire hydrant
# cap:horse
# cap:three bears in the water near a wall
# cap:the house the backyard, pool
# cap:a baseball player is throwing the ball
# negetive node_word:sports ball
# cap:a microwave in the woods
# cap:a yellow meter with a palm tree behind it
# cap:the person riding a horse
# cap:the boat is traveling in the water
# cap:a toilet is near a group of restaurant chairs
# negetive node_word:toilet
# cap:person carrying a surfboard in the ocean
# negetive node_word:person
# negetive node_word:surfboard
# cap:a young boy is playing tennis
# negetive node_word:person
# cap:boat sailing on the ocean
# cap:on the zebra
# cap:man is on his bike
# cap:woman on couch
# cap:two small planes flying in a cloudy sky
# cap:The person is holding their ski board in the air
# negetive node_word:skis
# cap:man is wearing a mask
# negetive node_word:person
# cap:a bear wearing a white suit is sitting on a chair with a sign in front of it
# cap:man is holding an umbrella
# negetive node_word:umbrella
# cap:train
# cap:a small black kitten sitting in an empty suitcase
# negetive node_word:suitcase
# negetive node_word:cat
# cap:light and people in the street
# negetive node_word:person
# cap:a tow truck with an open loader backed into a bus
# negetive node_word:truck
# cap:man wearing skis and helmet
# negetive node_word:skis
# cap:black train with red stripes on the front
# cap:bathroom sinks
# cap:a white building with white windows
# cap:pizza on pizza cutter
# cap:two double decker buses driving on the street
# negetive node_word:bus
# cap:apples are placed side by side,
# cap:small houses with train cars
# negetive node_word:car
# cap:a woman is in a tennis court
# cap:tree trunks
# cap:a man has a tennis racquet
# cap:three people on motorcycles ride down a road
# cap:people are walking around in hallway
# cap:Several boats are in the water, with a few boats docked next to a shore
# cap:three giraffes
# negetive node_word:giraffe
# cap:man in tie
# negetive node_word:tie
# cap:of the traffic light
# cap:people on snow
# cap:computer computer computer screen
# negetive node_word:laptop
# cap:i.e: the table is wooden, and there is a computer and bookshelf
# cap:a man is riding a skateboard in a skate park
# cap:a person is ski racing
# cap:laptop laptop desktop
# cap:woman with umbrella, boots and a bag
# cap:man sitting on couch
# negetive node_word:couch
# cap:elephant in the middle of the pond
# cap:man surfer is surfing
# negetive node_word:person
# cap:three zebras with a child in a pen
# cap:bird is red and brown
# cap:counters, sink and window
# cap:man standing on platform
# cap:two daisies in a square blue vase on a black surface
# cap:two grey train
# cap:the giraffe is brown and spots
# cap:the body of the surfer
# cap:two cats playing with shoes
# cap:the clock is on the top of the tower
# cap:man is standing in the ocean
# negetive node_word:person
# cap:the brown horse has a white man
# cap:the background
# cap:a woman sits at a white table in a room
# cap:Several train locomotives in a town
# cap:a man making pizza
# 100%|██████████| 499/499 [00:00<00:00, 1643.51it/s]
# negetive node_word:pizza
# cap:in brackets
# cap:horses grazing
# cap:the black parking meter
# cap:A woman is taking a picture of a woman with the baby on her lap
# cap:the toothbrushes are red
# cap:a room with two beds one with a wooden top
# negetive node_word:bed
# cap:woman
# cap:A tennis player is playing a game
# cap:street lights
# cap:a laptop on a desk
# cap:people are walking along the sidewalk
# negetive node_word:person
# cap:the person is sitting in a parking lot while standing on a skateboard
# negetive node_word:skateboard
# cap:the bricks in the ground were bricks
# cap:a brown plate of food with broccoli, parsley and cheese
# cap:- the horses are pulling a carriage, the people are sitting on the ground
# negetive node_word:person
# cap:the man is wearing a business suit
# negetive node_word:person
# cap:a city street with tall buildings
# cap:people are wearing t-shirts
# cap:a group of people are walking around with horses on the side of the street
# cap:there is a building with signs
# cap:man kneels down on top of snowboard in snow
# cap:woman walks down the street holding a bottle in her hands
# negetive node_word:bottle
# cap:man sitting
# cap:woman with a white blouse looking into the camera
# negetive node_word:person
# cap:the people are walking
# cap:boat docks with people on water
# negetive node_word:boat
# negetive node_word:person
# cap:the a group of people is making dough
# cap:a skier is racing down a ski slope with flags in the background
# cap:a green bench with a lantern
# cap:man skateboarding on steps
# cap:a big white table filled with a variety of food and drink
# cap:someone is skateboarding down a street
# cap:sinks
# negetive node_word:sink
# cap:blue, blue, blue, blue
# cap:two oranges on a plate sit next to a mouse
# negetive node_word:orange
# cap:person on chair
# negetive node_word:chair
# cap:lots of road signs on a pole on a street
# cap:people are holding kites and pointing them out as he walks
# cap:several cucumbers in a plate on the counter
# cap:cat is sitting on top of microwave
# cap:airplane in the sky on clouds
# cap:boat with basket of fruit
# cap:a plate of food on a wooden surface of a table
# cap:people eating pizzas out on the table
# cap:line of cars, vehicles on the street, people parked on street, people in cars, trees, buildings, people standing on street, cars
# cap:a rose is in a glass vase
# cap:teddy bear sitting in the middle of wood chips on a playground
# cap:people gathering around a pizza in a box
# negetive node_word:pizza
# negetive node_word:person
# cap:people playing tennis
# cap:herd of cows walking across a field
# cap:a woman riding an elephant, in a city
# cap:person cutting cake
# cap:toilets, toilet brush, and phone on a table
# negetive node_word:cell phone
# negetive node_word:dining table
# cap:two black brown duvets
# cap:face is dark
# cap:skier on skis
# negetive node_word:person
# cap:skate boarder in the air over railings
# cap:man is staring at a cake
# cap:the plane is flying
# cap:the sheep is looking to the camera and a white chicken is in the background
# cap:people on elephants riding on water
# cap:a black dog
# cap:a group of oranges on wooden board
# negetive node_word:orange
# cap:a cat is standing on the floor next to a black bag
# negetive node_word:cat
# cap:several sheep with long horns
# negetive node_word:sheep
# cap:a sofa
# cap:table and chairs
# cap:sheep are in the field near a fence
# negetive node_word:sheep
# cap:two motorcycles in the parking lot
# cap:two men running on a field
# cap:person riding a surfboard
# cap:A man is putting a suitcase into a trash can, on the sidewalk
# negetive node_word:suitcase
# cap:Two benches and a walkway surrounded by trees
# cap:seven donuts in a box
# cap:snow on the ground
# cap:street sign
# cap:the motorcycle has a front and rear view
# negetive node_word:motorcycle
# cap:woman in black bikini putting ball in net
# negetive node_word:person
# cap:a bench
# cap:a clock
# cap:three baseball players on a field
# cap:two people sitting at a table, eating food
# negetive node_word:dining table
# negetive node_word:person
# cap:the zebra and the tree
# cap:train
# cap:the road and streets
# cap:the sky
# cap:four beds are in the tent
# cap:person is wearing glasses
# cap:two woman and a cat
# cap:noodles, meat, vegetables, and toppings
# cap:parking sign with no parking
# cap:food
# cap:white plate with white dessert
# cap:a kitchen scene with a large amount of food arranged on a counter
# cap:white sail boat is sitting on the river in water
# negetive node_word:boat
# cap:items scattered on the bed
# negetive node_word:bed
# cap:two girls playing tennis
# cap:men carrying a kite
# negetive node_word:kite
# cap:a wooden bed with a headboard and a railing
# cap:a brown bear, standing in a waterfall
# cap:a train is on a track
# negetive node_word:train
# cap:three colorful cows standing
# cap:airplane is parked
# cap:the hydrant is sitting
# negetive node_word:fire hydrant
# cap:an old clock sitting on a wall
# cap:people in cowboy hats riding horses
# negetive node_word:horse
# negetive node_word:person
# negetive node_word:person
# cap:the cooking pot is large
# cap:child wearing red and brown pants
# negetive node_word:person
# cap:horse pulling a carriage with a man in it
# negetive node_word:horse
# negetive node_word:person
# cap:no bottles allowed on sidewalks sign, street, stairway
# negetive node_word:bottle
# cap:a bed in a room
# cap:people standing in a field watching other people
# cap:- sex shop
# cap:three policemen standing in front of motorcycles
# negetive node_word:person
# negetive node_word:motorcycle
# cap:white cat sitting on top of computer
# cap:orange flower on napkin
# negetive node_word:orange
# cap:people are watching a herd of elephants
# negetive node_word:person
# negetive node_word:elephant
# cap:a stone statue in a square garden near white flowers
# cap:the room is white and the walls are wood
# cap:table in the middle of the room with a tray of beverages sitting on it
# cap:a ham burger burger on a plate
# negetive node_word:sandwich
# cap:a woman is throwing an orange frisbee
# negetive node_word:orange
# cap:bear is tan
# negetive node_word:bear
# cap:a person is holding a water bottle
# negetive node_word:bottle
# cap:teh kites are in the air
# cap:giraffe is eating
# cap:bunches of yellow bananas hang from the tree
# cap:various flowers sit next to a table
# negetive node_word:dining table
# cap:bird
# negetive node_word:bird
# cap:Several players playing on a baseball field with a crowd watching
# cap:oranges inside of a box
# negetive node_word:orange
# cap:a person sits next to suitcases
# negetive node_word:suitcase
# negetive node_word:person
# cap:man in armour and helmet riding on a horse
# cap:building and clock tower view of a city
# cap:several zebras in the field
# cap:two bicycles with heads
# cap:three people sitting on snow
# cap:people are playing frisbee on a golf course
# cap:people are standing near a bus
# negetive node_word:person
# cap:polar bear eats carrot off the rocks
# cap:a large bus stops to wait next to a bus stop
# cap:person sits on a wall
# cap:the clock
# negetive node_word:clock
# cap:a sign and a house
# cap:a white umbrella
# cap:boat with people on it in the middle of water with trees, sun, sand
# cap:an airplane is flying
# cap:the pole has street sign on it
# cap:people riding horses
# cap:two white buildings are in the background
# cap:person walking with a child
# negetive node_word:person
# negetive node_word:person
# cap:a man jumps in the air
# cap:computer monitor on the desk
# SPICE	METEOR	CIDEr	CHAIRs	CHAIRi
# 0.0	0.0	0.0	25.7	27.9

# %%
#cap_file = "C:/Users/hutter_sadan/Desktop/UCAS/blip2/data/VG_BLIP2_6_original.json"
cap_file = "C:/Users/hutter_sadan/Desktop/UCAS/blip2/data/VG_BLIP2_500_6.json"
_, imids = load_generated_captions(cap_file,True)
print(imids) 
evaluator = CHAIR(imids) 
evaluator.get_annotations()
print(len(imids))
cap_dict = evaluator.compute_chair(cap_file)     
print_metrics(cap_dict)
# Out:
# 100%|██████████| 499/499 [00:00<00:00, 166305.74it/s]
# {2365441, 2412553, 2344971, 2357261, 2334734, 2351119, 2349075, 2416667, 2367520, 2316323, 2094, 2332720, 2353201, 2349105, 2379830, 2369602, 2361413, 61513, 2396236, 2365521, 2345047, 2336859, 2361437, 2318429, 2334815, 2355297, 2394217, 2359410, 2392180, 2377845, 2402423, 2336889, 2355322, 2332801, 2326662, 2367625, 2369674, 2347152, 2416784, 2338980, 2343083, 2412716, 2400432, 2379952, 2379960, 2322620, 190, 2400447, 2373826, 2375883, 2347213, 207, 2384079, 2406615, 2330845, 2373855, 2345189, 2394341, 2398439, 2392298, 2398446, 2355445, 2414850, 2359559, 2392331, 2377997, 2318614, 2404631, 2378006, 2398486, 2324762, 2335005, 2416934, 2347306, 2382124, 2349, 2320689, 2345270, 2410806, 2378041, 2332986, 2345277, 2318667, 2388317, 2400606, 2328928, 713057, 2361698, 2363755, 2361709, 2392431, 2369904, 2316658, 2374002, 2326905, 2406783, 4479, 2351487, 2341257, 2386314, 4494, 2400655, 4503, 2367895, 2363805, 2363806, 2341280, 2351526, 2363815, 2320815, 2367925, 2337205, 2345406, 2396607, 2400702, 2363844, 2388422, 2322889, 2415062, 2406871, 2404825, 2337248, 2339312, 2327027, 2343418, 2367997, 2339325, 2400767, 2335234, 515, 2382339, 2341381, 2394630, 2341383, 2335238, 2413073, 2318866, 498202, 559, 2339378, 2411065, 2337340, 2386496, 2335297, 2394694, 2347592, 2333257, 2316880, 2363985, 2345554, 2323027, 2351702, 2384473, 2388575, 2388576, 2343521, 2382435, 2378341, 2404968, 2370162, 2370170, 2316924, 2329213, 2691, 2415236, 2400899, 2392713, 2372237, 2370193, 2337427, 2400919, 2402972, 2337441, 2732, 2351792, 2394804, 2362040, 2405050, 2343611, 4798, 2382539, 2396878, 2370263, 2388701, 2380512, 2321123, 2360036, 2380515, 2415341, 2411252, 2398967, 2341626, 2319098, 2398971, 2325246, 2353920, 2360064, 775, 2355976, 2403083, 2390799, 2335505, 2409234, 2836, 2351894, 2331417, 2351899, 2370338, 2368293, 2317094, 2370357, 2370358, 2343737, 2358075, 4925, 2335554, 2384706, 2349912, 2351961, 713563, 2351965, 2407264, 2319202, 2341731, 2388841, 2341739, 2327404, 2351985, 2409331, 2415485, 2337661, 2343805, 906, 2370454, 2403224, 2319256, 2405280, 2329508, 2368424, 2319282, 713651, 2388924, 2356158, 2399167, 150468, 2327494, 2403271, 2407376, 2368469, 2325477, 2329585, 2343921, 2343928, 2384889, 2417657, 2362365, 2356231, 1160200, 2325513, 2411532, 1037, 2323470, 150541, 2360336, 2337809, 2337810, 2362384, 2376725, 1592350, 2393119, 2354215, 2417712, 2401329, 2399281, 2411573, 2376760, 2333757, 2384957, 2399296, 2401354, 2339929, 2350170, 1592412, 2344039, 2319463, 2387049, 1131, 2366571, 2344045, 2376815, 2356336, 2368623, 2378866, 713839, 2385014, 2366584, 2354301, 2331774, 2329726, 2337920, 2387077, 2409606, 2366607, 2321553, 2329748, 2397335, 2337946, 2403486, 2325665, 2337958, 2417831, 2329769, 2385076, 2415800, 2319549, 2405566, 2340034, 1220, 2383046, 2323663, 2376913, 2387155, 2395348, 2366682, 2409690, 2372833, 2399459, 2387173, 2327785, 2376942, 2385134, 2354430, 1282, 2411778, 2409749, 2401566, 2340128, 2381099, 2325806, 2399541, 1337, 2372924, 2417985, 2405698, 2356547, 2315591, 2407751, 2329931, 2358604, 2403662, 2399566, 2321744, 2350418, 2342232, 2336097, 2332006, 286057, 2385261, 2403697, 2372978, 2405747, 2389367, 2327929, 2381181, 2385278, 2352515, 2407812, 2329991, 2411918, 2330000, 2413990, 1592748, 2319790, 2338222, 2385330, 2416059, 2381245, 2403781, 2409926, 2391495, 2350539, 2395597, 2321869, 2385360, 2385363, 2383320, 3550, 2319844, 2383334, 2379246, 2416112, 2414065, 2336246, 2346490, 2340352, 2321922, 2405902, 2391575, 2416151, 2324000, 2350635, 2381358, 2360879, 2373168, 2399794, 2391615, 2340416, 1602, 2358853, 2350664, 2344526, 2391633, 2367061, 2403928, 2338399, 2416226, 1635, 2375266, 2408040, 2352750, 2365041, 2385536, 2373258, 2408079, 2315923, 2412183, 2381473, 2406050, 2395813, 2399920, 2410161, 2397875, 2410185, 2361036, 2320078, 2391761, 2410197, 2373334, 2361046, 2369245, 2410205, 2342628, 2385638, 2354919, 2414318, 2404080, 2361074, 2399988, 2397947, 2352896, 2340614, 2316039, 2373392, 2391826, 2 ...
# 100%|██████████| 108077/108077 [00:00<00:00, 1286636.56it/s]
# 100%|██████████| 396/396 [00:00<00:00, 195359.25it/s]
# 499
# 100%|██████████| 499/499 [00:00<00:00, 248186.61it/s]
#  31%|███       | 154/499 [00:00<00:00, 1539.59it/s]
# cap:a bed in modern living room with a big television
# cap:ostriches are eating in the grass near their zebra counterparts
# negetive node_word:zebra
# cap:tall buildings in a city with a white fence and a blue sky
# cap:some indian food on metal tray
# cap:the stone tombstone of st michael church
# cap:a street corner with a traffic light and street sign
# cap:some flags are hung by the water and on a pier
# cap:a boy does a trick on his skateboard and doing a trick in the street
# cap:a young boy holds up a tie
# negetive node_word:person
# negetive node_word:tie
# cap:about 100 and many people are watching the tennis match
# cap:a basketball game with two basketball players in motion
# cap:a man is walking by a sidewalk with benches
# negetive node_word:bench
# negetive node_word:person
# cap:men look at a bear
# cap:a bed and pillows next to a window
# cap:A small plane in the sky with a runway
# cap:a man sitting on a dirt bike next to a tree
# negetive node_word:bicycle
# cap:a tennis player is about to hit a tennis ball with a tennis racket
# negetive node_word:sports ball
# negetive node_word:tennis racket
# negetive node_word:person
# cap:a person is going skiing down a snowy hill
# cap:two boys are skateboarding down a sidewalk at a skate park
# cap:a man is walking down the street while waving his tennis racket in front of a crowd
# cap:A man and woman smile and grin while eating breakfast
# cap:two boys in equestrian costumes
# negetive node_word:person
# cap:a person riding down a hill on a snowboard and creating some snow
# cap:a skateboarder doing a trick on a railing
# cap:a man tying a tie to make his arms make a cross
# negetive node_word:tie
# cap:A man is playing tennis as the crowds watch
# cap:boat near a dock and boat near the shore
# cap:a table in a restaurant
# cap:a plate of bananas and banana
# cap:a blue and green plane is winging it's way through the sky with a blue trail that resembles a yellow smoke streak
# negetive node_word:airplane
# cap:a man is eating a doughnut
# negetive node_word:donut
# cap:the tree line has no bare branches
# cap:a man and a man are riding a boat
# cap:a living room with a couch and a chair and some lamps
# cap:people in bikinis walking to the beach
# cap:The man has a big red luggage
# negetive node_word:person
# negetive node_word:suitcase
# cap:a dog sits on a leash in the front seat of a car
# cap:man swings a tennis racquet on a court
# cap:a boy hitting a tennis ball with tennis racket
# negetive node_word:person
# cap:this living room has a wooden appearance with a tv on the fireplace and hardwood in the floors
# cap:a yellow cab drives down a city street at night
# cap:a person riding a wave on a surfboard
# cap:Several people are riding on kites as they walk in the ocean during a stormy day
# negetive node_word:person
# cap:several cars on a city street
# cap:a dog walking in a street or side of the road
# cap:tile and a sink, a toilet, and a tub
# negetive node_word:toilet
# cap:a plate of food and a glass of wine
# cap:talking on the cell phone while eating and eating with a knife and fork
# negetive node_word:knife
# cap:The elephants are laying down at their enclosure, in a fenced area with a rock
# negetive node_word:elephant
# cap:the podium with 3 people on each
# cap:a woman is walking on a circular pedestal with a cell phone on it
# cap:a desk with a fan and computer on it
# negetive node_word:laptop
# cap:The bathroom has towels hanging up and a mirror on the wall
# cap:a white teddy bear wearing a tiara is posing with a paper cup
# cap:a group of young people using their computers on a floor
# negetive node_word:laptop
# cap:a person is doing tricks on an skateboard
# cap:A person on a tennis court swinging a racquet as she waits for the ball to hit a tennis ball
# cap:a banana merchant looks at the bananas hanging in a banana market
# cap:the team posed and posed for this photo for the photo album
# cap:a bathroom with a toilet and some other toiletries
# cap:A bento box full of foods, vegetables, apples and skewered food
# negetive node_word:apple
# cap:a woman on the tennis court holds up a racquet
# cap:five stuffed bears on shelf
# cap:giraffe with a long neck and a long neck reaching
# negetive node_word:giraffe
# cap:A person skateboarding and riding a skateboard
# cap:this toilet is dirty and it's dirty
# negetive node_word:toilet
# cap:a bunch of flowers in a vase and on a tv set
# negetive node_word:tv
# cap:three young boys are standing outside a skate bowl, talking about their skateboards
# negetive node_word:bowl
# cap:on a plate next to a slice of a pie is a tea spoon and a coffee mug
# cap:two elephants are touching each other's trunks near rocks
# cap:a person demonstrates some of the ski moves he performs
# negetive node_word:skis
# cap:a surfer surfing in the ocean
# cap:small airplane flying above mountains in switzerland
# cap:bicycles in a store
# negetive node_word:bicycle
# cap:two teddy bears are cuddling with a child
# negetive node_word:person
# negetive node_word:bear
# cap:a group of elk in grass
# cap:a man hits a tennis ball while playing tennis
# cap:two laptops in a living room with television on one, and windows on the other
# cap:people on horses herding sheep
# cap:a group of people standing around an airplane on a hangar
# cap:two crowded buses traveling down a busy street
# cap:a machine with doughnuts on it is running through the factory
# cap:living room and bedroom
# cap:the girl is checking the time and looking at the cell phone
# negetive node_word:cell phone
# cap:Two plates of pizza with wine glass on top
# cap:A duck walks in a green grass and walks next to a metal fence
# cap:three cows stand next to a fence
# cap:a guy dressed in a santa Claus suit
# negetive node_word:person
# cap:The birds are sitting on plates on a table
# cap:person takes a selfie in bathroom
# cap:a baseball player is about to swing at a pitch
# cap:a jet fighter on the ground
# cap:the station with its train platforms and the clock showing the time
# negetive node_word:train
# cap:a woman on a rock in water next to the water
# cap:a parked car beside a grey and brown building
# cap:a cow in a field
# cap:three women drinking beer
# cap:an airliner is sitting on the runway at the airport
# cap:The bus was covered in snow on its stop and is parked in front of a building
# cap:fork and fork on top of cake
# cap:A plate with a sandwich, fries and a glass of red wine
# cap:six people sitting around a round table eating food
# cap:the dogs are wet in the car
# cap:There is a stop sign at the top of a fence
# cap:this home has white cabinets and black counter tops
# cap:girl with a sandwich and a hot dog
# negetive node_word:dog
# negetive node_word:sandwich
# cap:zebra and buffalo walking together
# negetive node_word:zebra
# negetive node_word:cow
# cap:cars are parked on the street
# cap:the elderly woman is playing with a wii game
# cap:a toilet with a remote control and a remote on the left side
# negetive node_word:remote
# cap:man taking a selfie in mirror taking a selfie, with glasses in the mirror
# cap:a living room with fireplace
# cap:tall building with a clock clock beside a tall flower
# cap:train at the station with doors on the front and side of the train
# negetive node_word:train
# cap:a group of people flying kites
# cap:a cat lays on a lap top
# cap:a man is flying his kite near a snow covered lake
# cap:polar bears in a zoo habitat
# cap:a crowd of people watching a skateboarder
# cap:two large elephants standing together
# cap:A man carrying a Surfboard along the street
# negetive node_word:person
# negetive node_word:surfboard
# cap:a plane parked at an airport
# cap:no bike lane and no parking street sign
# negetive node_word:bicycle
# cap:an old pickup truck parked in snow
# negetive node_word:truck
# negetive node_word:truck
# cap:a laptop is on the table
# cap:a player stands in the batting cage with their bat
# cap:a cart with a refrigerator is on a sidewalk with a person in a wheelchair
# negetive node_word:refrigerator
# cap:the city of london seen from a hilltop
# cap:on the grass and on the grass is a laptop
# negetive node_word:laptop
# cap:a plate with toast, eggs, eggs and scrambled eggs
# cap:a large number of birds flying over a city
# cap:a man posing with his cell phone in his hand
# negetive node_word:cell phone
# cap:umbrellas hanging from the ceiling at the entrance
# negetive node_word:umbrella
# cap:a lone blue cab
# negetive node_word:car
# cap:a man and woman on a motor bike ride down a street on a motorcycle
# negetive node_word:motorcycle
# cap:A woman reading a book as she prepares to board a train
# negetive node_word:book
# negetive node_word:train
# cap:a city has several blue bikes
# cap:Two elephants walking near a creek
# cap:a man skateboarding in the air while doing a skateboard trick
# negetive node_word:person
# negetive node_word:skateboard
# cap:a pet dog is walking on its skateboard by wearing a vest
# negetive node_word:skateboard
# negetive node_word:dog
# cap:a student room with a bunk bed, a desk, two shelves and a bookcase
# negetive node_word:person
# cap:an empty bathroom with a toilet and sink
# negetive node_word:sink
# cap:a man is laying down in the grass fixing a skateboard
# cap:a toddler is standing in front of a stainless steel refrigerator
# cap:an image of a parking meter outside a city
# cap:pizza is on the plate next to a laptop
# negetive node_word:pizza
# cap:A laptop and a computer are on the desk
# cap:two jet planes flying over an airport in the sky with some trees
# cap:A grey and white cat stares at an open laptop and window
# cap:A gray street in a city
# cap:people are holding umbrellas in a flooded street
# cap:chinese and asian sign in the middle of water at a city
# cap:a girl is playing wii
# cap:a girl dipping a plate in a pink sauce while a little girl watches
# cap:an old man is riding a motorcycle on a street in front of a store
# cap:a truck with people on it that crashed during an accident in a dirt road, emsley county, 1907
# cap:A group of people are playing frisbee outside in a park
# cap:two motorcycles in a parking lot
# negetive node_word:motorcycle
# cap:a giraffe near a tall fence
# cap:the car positioned on the side of the road next to a train
# cap:A race at night with a dirt road
# cap:a small boy is eating food outdoors
# negetive node_word:person
# cap:white farmhouse with black clapboard siding in the u
# cap:an upstairs living room
# cap:Two people are talking on the stairways while standing on a bench
# cap:a fire hydrant with people looking at it
# negetive node_word:fire hydrant
# cap:A toothbrush on a surface with black
# negetive node_word:toothbrush
# cap:a clock tower with a pole next to it and some signs on a street
# negetive node_word:clock
# cap:a glass of wine on a railing with a view of a green forest
# cap:an elderly man is a carriage pulling a person in the town square
# cap:boys playing frisbee on a green field
# negetive node_word:frisbee
# cap:a bookcase full of books and books on the mantel
# cap:a kitchen table with vegetables on it
# cap:man on beach standing in water
# cap:the sign on the pole is pointing toward the venice canals walkway
# cap:this is a vignette of two old people holding baskets
# negetive node_word:person
# cap:two dogs running through a dirt path
# cap:four photos of birds sitting in different positions on a branch
# cap:a woman wearing a black hat while talking on the phone
# negetive node_word:cell phone
# cap:two bald men standing near a man holding a purple umbrella in front of a wall
# cap:the zebra is eating and grazing in a green grassy field
# cap:a coffee cup beside a cake and dessert plate
# negetive node_word:cake
# cap:a desk with a monitor, computer, laptop and two cords
# negetive node_word:laptop
# negetive node_word:laptop
# cap:a man is standing next to 2 phone booths
# cap:a green, double decker bus is parked in front of a brick building
# cap:small boy on a skateboard
# negetive node_word:person
# cap:There are many animals on a hill. Some giraffes, rhinos, and zebras are grazing together
# negetive node_word:zebra
# cap:birds, airplanes and a skyscraper fly through the city
# negetive node_word:airplane
# negetive node_word:bird
# cap:cat and photo on top of a cake
# negetive node_word:cat
# negetive node_word:cake
# cap:blue sky with clouds
# cap:A person wearing a wig with a hat playing with a cat
# cap:people are walking by a bench while standing in a field
# cap:A man skateboards through the air doing some tricks
# cap:the man sitting on his bench and on a bench
# cap:A baseball player is at bat in the middle of the dirt field
# cap:a cat eats carrots and licking the green tops
# cap:a city has a clock tower in the center of a town
# cap:red ducati motorcycle parked next to black and white building
# cap:walking and walking next to a bus
# cap:an old wooden boat lies on the ground by a group of people
# cap:an orange and black passenger train is waiting to be pulled up at train station
# negetive node_word:orange
# cap:the mom drinks coffee and the boy sleeps while they sit on the bed
# cap:in the kitchen and on a table - photo by jonathan brittain
# cap:A clock tower is shown on top of a brick and mortar building
# cap:A person is playing with a dog on a beach.
# cap:some people are waiting near the train station
# cap:a man is holding two nintendo wii controllers
# cap:a car located on a street
# cap:a zebra grazes while another stands behind him
# negetive node_word:zebra
# cap:a white and red bedroom with two large double beds and a sofa bed
# negetive node_word:couch
# negetive node_word:bed
# cap:a white cabinet and sink in a bathroom
# negetive node_word:sink
# cap:white jet plane in the sky
# cap:lots of buses and cars on this street - a city
# cap:a living room has a coffee table and red couch
# negetive node_word:couch
# cap:Chocolate cake on plate
# cap:a boy and a dog on a walk
# cap:a plate of food with a sandwich and some potatoes
# negetive node_word:sandwich
# cap:cat on sofa looking into camera
# negetive node_word:couch
# cap:traffic light with street sign
# cap:There are plates full of different kinds of food
# cap:There is a giraffe standing in the field
# cap:mother monkey has banana
# cap:there are still a few bottles of wine in the sand and it is in a state of disrepair and is in a state of disrepair and is in a state of disrepair
# negetive node_word:bottle
# cap:the field has a kite flying over it
# cap:A stop sign is on the street with an arrow pointing to the right
# cap:a pizza in box on a picnic table
# negetive node_word:dining table
# cap:a clock tower with lights at the top
# cap:white fire hydrant at the end of the curb and near the sidewalk
# negetive node_word:fire hydrant
# cap:four trains are on track
# cap:a city with a dock and boats on a calm day
# cap:a street with a fire hydrant at the corner
# negetive node_word:fire hydrant
# cap:a red and white big airplane on the runway
# cap:A man is writing on a suitcase
# negetive node_word:suitcase
# negetive node_word:person
# cap:a big tower in the middle of a garden
# cap:two men riding horses
# cap:jets
# cap:A woman in hat and pink walking her dog
# cap:the truck is hauling a large truck
# cap:A woman is skiing down a hill. She is surrounded by spectators.
# cap:A plane is taking off from an airport runway.
# cap:a person is playing frisbee with some children
# cap:a motorcycle is parked in the sidewalk of a house in front of a tree
# cap:old toilets, one on each corner of a garden
# negetive node_word:toilet
# cap:A girl is throwing a frisbee on to fallen log in the park
# cap:a yellow plane on a tarmac
# negetive node_word:airplane
# cap:two people are riding bikes on a grassy field with a sheep in sight
# cap:A train on the tracks next to trees and bushes
# cap:a man is playing frisbee in the field
# negetive node_word:frisbee
# negetive node_word:person
# cap:the view out of the window of a train
# cap:the front of a large building
# cap:the man is holding the board up to the sun with a picture of a shark on it
# cap:People in grass on a frisbee
# cap:A woman surfing in the ocean on a surfboard
# cap:a pizza is sitting on a rack inside a pizza oven
# negetive node_word:pizza
# negetive node_word:oven
# cap:A train is on the tracks and at a station.
# cap:snow and skis
# cap:an urn in the yard
# cap:there is a pink and pink teddy bear sitting on suitcases
# negetive node_word:suitcase
# cap:two large elephants are standing around
# cap:a dog stands on a beach next to the ocean
# cap:a yellow passenger train sits in the train station
# cap:a person is on a beach flying a kite
# cap:naked young man in bed
# cap:a white teddy bear is listening to some of his friends singing
# negetive node_word:bear
# cap:person making toast with a spatula
# cap:a biplane hung by a wing in a museum
# negetive node_word:airplane
# cap:a red mail box in street
# cap:a man is brushing her teeth and a man is brushing his teeth
# cap:a skateboarder in the air
# cap:sliced toast and eggs on a plate with ham and cheese
# cap:wine glasses in a castle courtyard
# cap:riding a horse on the beach
# cap:a grey van and an rv driving down the main st in a hampton riverside area
# cap:two police officers in dark clothing, riding scooters
# cap:a jet flying
# cap:man and woman wearing ties
# cap:there are a number of trees on a grassy field
# cap:train tracks and a passenger train
# negetive node_word:person
# cap:a group of men spraying water on a fire hydrant
# negetive node_word:fire hydrant
# cap:two horses in a field sniffling one another
# cap:bears play in the water
# cap:this is a pool house photo for sale in the new brockton massachusetts area of the state
# cap:a player is preparing to swing at a football during a baseball game
# cap:A microwave oven in a desert in the sun
# negetive node_word:oven
# cap:a parking meter in front of a building
# cap:Two horses and a woman are riding on a dirt track
# cap:a boat is passing by a river
# cap:the san diegan tavern in the old town in houston,texas san diego tavern
# cap:The man is in the water surfing, holding a surfboard
# negetive node_word:person
# negetive node_word:surfboard
# cap:this boy is playing tennis with a racket on the court
# negetive node_word:person
# cap:a boat in choppy waters with a sail and a silhouette
# cap:zebra grazing on the grass
# cap:man riding his bicycle on a city street with buses
# cap:A woman is sleeping and sitting on a couch in a living room
# cap:Two airplanes flying in the sky
# cap:A person is standing next to a snow board while they watch an event
# cap:the two people stand together in the background
# negetive node_word:person
# cap:sitting in a chair
# cap:football players holding umbrellas
# negetive node_word:umbrella
# cap:a train passing by a building next to a train track
# cap:a person reaches into a suitcase to pull out a black pet in it
#  62%|██████▏   | 308/499 [00:00<00:00, 1496.02it/s]
# negetive node_word:suitcase
# negetive node_word:person
# cap:traffic signal lights on t-post next to a building
# cap:a bus that has been overturned
# cap:A man descending a mountain with skis
# negetive node_word:skis
# cap:a black train parked next to a white picket fence
# cap:there is soap, two sinks, a shower, and a toilet in the bathroom
# cap:two trucks in an open lot and in front of a building
# cap:A large pizza is sitting on top of a BBQ grill
# cap:two decker buses on a road in london
# negetive node_word:bus
# cap:apple in a pile
# cap:a wooden train tracks next to a house and a house
# cap:a woman wearing a blue shirt and green shorts is on a tennis court swinging a ball and hitting a tennis racket
# cap:a bench in the woods
# cap:three men on a tennis court playing with tennis rackets
# negetive node_word:tennis racket
# cap:motorcycles on motorcycles on the road
# cap:a group of people standing in one large room
# cap:boats are docked in the water in a marina
# cap:there is one of a giraffe and several other giraffe
# negetive node_word:giraffe
# cap:a person taking a selfie in a bathroom
# cap:the traffic light is rusty and the background is white and white
# cap:A person dressed in an animal suit carrying a ski board
# negetive node_word:skis
# cap:the cat watches the computer monitors and sits on the desk
# negetive node_word:laptop
# cap:i like this
# cap:a man skateboards down a hill with his board in a bowl
# negetive node_word:bowl
# cap:the woman is at the start of a race on the skis
# cap:a laptop with a black color open next to a coffee mug
# cap:a woman carrying an umbrella in the rain
# cap:a man sitting in a room laying down
# cap:an elephant standing next to a tree
# cap:A man surfs on a wave in the ocean
# negetive node_word:person
# cap:two zebras - mother and young - stand around a tree
# cap:bird standing on a table
# negetive node_word:dining table
# cap:A kitchen that has a sink and stove
# negetive node_word:oven
# cap:a woman in a red dress is standing next to a train on a platform
# cap:two square vases with daisies in them
# cap:two trains with two passengers
# negetive node_word:person
# cap:giraffe staring at the camera in a zoo
# cap:young woman running on the beach and holding a surfboard
# negetive node_word:person
# negetive node_word:surfboard
# cap:kitty cat kicking shoes and playing with them
# cap:a church with a clock tower and clock
# cap:man flying kites in water with people standing on beach
# negetive node_word:person
# negetive node_word:person
# cap:the man is holding the horse's head and leans against the fence
# cap:a herd of giraffes in grasses
# cap:a woman is working on her computer at a desk with wood studs around the edges of the wall
# cap:A train traveling down tracks in a rural area surrounded by trees
# cap:a man making pizza in a kitchen
# negetive node_word:pizza
# cap:the street sign and the hollywood sign are on the pole
# cap:a horse and other animals are in a field eating and grazing
# cap:street scene with parking meters
# cap:two children eating pizza in the kitchen
# cap:this is a bathroom
# cap:the room is dark with light wood
# cap:a woman in white is playing tennis
# cap:A man is serving the tennis ball while other players await the ball
# cap:neon signs and a toyota sign, a toyota sign, a toyota sign, a toyota sign
# cap:a laptop, fish tank, and a bottle of liquor on desk in a bedroom
# cap:paved streets of a city
# cap:the man on the skateboard is watching some trucks and the trees
# negetive node_word:skateboard
# cap:Two babies play together next to a fire hydrant
# negetive node_word:fire hydrant
# cap:mushrooms, broccoli, and white rice with cheese
# cap:a horse drawn cart pulling a crowd of people and riding down the street in front of a carnival cruise ship
# negetive node_word:person
# cap:a bird's nest hanging in the air with a tan colored wing on it in front of a brick wall
# negetive node_word:bird
# cap:a city street scene showing a decker bus
# cap:a group of people are standing in one place holding flags
# cap:some kids riding horses and motorcycles in the city
# negetive node_word:motorcycle
# cap:a street in japan and in a city
# cap:A man is getting ready to jump off a snowboard onto his skis
# negetive node_word:skis
# cap:a woman carrying a water bottle down the street
# negetive node_word:bottle
# cap:sit on a bench
# cap:three women in an auditorium
# negetive node_word:person
# cap:there are two people on the street riding horses
# cap:a lake with a lot of boats in it
# negetive node_word:boat
# cap:group of people are making bread
# cap:A skier is racing down a mountain in the snow
# cap:an old green bench on a porch
# cap:a skateboarder doing stunts under a bridge
# cap:many people and plates on the table
# cap:The man is skating down the street while other people are skating along the street
# negetive node_word:person
# negetive node_word:person
# cap:a black and white bathroom with a sink and window
# negetive node_word:sink
# cap:in a field a fire hydrant
# negetive node_word:fire hydrant
# cap:on a plate with an orange and an egg
# negetive node_word:orange
# cap:a woman sitting at a table
# cap:street sign on a pole
# cap:a boy is flying a kite in a park with people watching
# cap:some vegetables that are laying beside the sink
# cap:it is cold
# cap:a plane flying high in the sky
# cap:boat on the water with banana and bananas
# cap:A plate with meat, wine and bread on it
# cap:people eating pizza on a table near a wall
# cap:A road is full of cars parked in the side of the road, with people riding scooters
# negetive node_word:motorcycle
# cap:one blue rose on a vase
# cap:a teddy bear is laying in a pile of mulch
# cap:A group of people are eating pizza
# negetive node_word:pizza
# negetive node_word:person
# cap:a full-sized tennis court
# cap:large herd of cows in the field
# cap:a man riding an elephant on the street
# cap:A person is holding a knife and is cutting a cake with a knife
# cap:several toilets in the bathroom
# cap:a man is working on his laptop as he waits to be moved
# cap:man with dark hair wearing a white tie
# negetive node_word:tie
# cap:man skiing down a snowy slope with barefooted
# negetive node_word:person
# cap:a man is jumping his skateboard in and doing a skateboard trick
# cap:man in front of cake
# cap:lufthansa plane taking off
# cap:the sheep is looking at something and standing next to a chicken
# cap:people and elephants riding down a river
# cap:A dog laying inside a blanket
# cap:an orange on a tray with a knife
# negetive node_word:orange
# negetive node_word:knife
# cap:a cat pawing at a bag in a bookshelf
# negetive node_word:cat
# cap:three sheep in a field
# negetive node_word:sheep
# cap:the cow hide rug is woven with cowhide
# negetive node_word:cow
# cap:i liked this picture, because it showed the table as opposed to the person
# cap:sheep in a pen
# negetive node_word:sheep
# cap:two black motorcycles are parked near some water
# cap:Two men are on a field playing frisbee in a field
# negetive node_word:frisbee
# cap:a surfer at the edge of a tube
# cap:a man is walking past the sidewalk near a trash can
# cap:there are wooden benches with trees in the background
# cap:6 donuts are sitting in a box with sprinkles
# cap:a boy is wearing a black coat while skiing
# cap:a traffic light with a blue street sign and some traffic going by
# cap:a motorcycle is sitting on a street
# negetive node_word:motorcycle
# cap:a woman jumping for the net after being hit by a ball in the sand
# negetive node_word:person
# cap:a long path with some hedges and bushes in a garden
# cap:a clock has been carved into a wooden structure on a building
# cap:baseball player swings his bat
# cap:twilight of an awesome dinner with the family
# cap:two zebras standing in the grass together
# cap:A train is sitting under the bridge at a station
# cap:the bus has a colorful pattern on the side and the top of it
# cap:A boy is riding a skateboard and doing a skateboard trick in front of a park
# cap:two beds in a tent with two lamps
# cap:a young lady in glasses, a shirt and tie posing for a photo
# negetive node_word:tie
# cap:two women playing the wii
# cap:this bowl of pasta is filled with couscous noodles, broccoli and tomatoes
# negetive node_word:bowl
# negetive node_word:broccoli
# cap:a large no parking sign is posted on a street pole
# cap:hot dog, a beer, and salad
# cap:a plate of toasted donuts, peaches, and drizzle
# cap:The kitchen counter in a rv is full of bread and fruits and vegetables
# cap:a person on a bicycle with a sail boat on the water with clouds in the sky
# negetive node_word:bicycle
# negetive node_word:boat
# negetive node_word:person
# cap:a backpack and other items
# negetive node_word:backpack
# cap:A tennis court with two people playing a match with their tennis rackets
# cap:two men hold up an american flag kite
# negetive node_word:kite
# cap:old wooden bed, with a wooden bench
# negetive node_word:bench
# cap:a bear is catching a fish by the waterfalls
# cap:a steam engine sitting in the middle of the dirt tracks on a sunny day
#  92%|█████████▏| 458/499 [00:00<00:00, 1175.54it/s]
# cap:a small group of ceramic and plastic bulls
# cap:an airplane is parked on the tarmac
# cap:a fire hydrant next to a house in front of a house
# negetive node_word:fire hydrant
# cap:a very decorative tall clock in a church
# cap:a group of people are all sitting atop a horse.
# negetive node_word:horse
# negetive node_word:person
# cap:vegetable soup and vegetables are cooking indoors in a pan on the stove
# cap:the young boy has a teddy bear in his mouth and is looking at it in the medical room
# negetive node_word:person
# cap:A white horse pulling a carriage
# negetive node_word:horse
# cap:a sign that says no bottles are allowed on the street in new orleans
# negetive node_word:bottle
# cap:there is a bed in this room that does not fit in the pictures
# cap:People fly kites in the park with a butterfly kite
# cap:many bags sit outside storefront
# cap:policemen sitting on motorcycles
# negetive node_word:person
# negetive node_word:motorcycle
# cap:white cat sitting on desk
# negetive node_word:dining table
# cap:a square table napkin in a white and white pattern with a single flower on it
# negetive node_word:dining table
# cap:a large group of people standing around a herd of elephants at a beach
# negetive node_word:person
# negetive node_word:elephant
# cap:a fountain in flowers and green grass in a park
# 100%|██████████| 499/499 [00:00<00:00, 1238.21it/s]
# cap:a bedroom with a bed that is made up and a bed
# cap:a vase in a metal vase is on the table in the lobby of a business building
# cap:ham and eggs on a plate
# cap:a frisbee thrown by a woman playing frisbee
# cap:A teddy bear wearing a bow tie is laying on a chair surrounded with a blue fabric
# negetive node_word:tie
# negetive node_word:chair
# negetive node_word:tie
# negetive node_word:bear
# cap:a man drank a water bottle while a dog ate it from his hand
# negetive node_word:bottle
# cap:a kite with a red octopus flying above a man
# cap:in a zoo and in a zoo
# cap:many bananas are hanging on a tree
# cap:vases of a lot of different kind of flowers are on a table
# negetive node_word:dining table
# cap:flock of birds atop a beach surrounded by the sea and lighthouse
# negetive node_word:bird
# cap:A person watching a baseball game
# cap:a lot of oranges in a bowl
# negetive node_word:orange
# cap:there are many suitcases that are not in order on the ground
# negetive node_word:suitcase
# cap:a knight riding a horse
# cap:a city in a view
# cap:the herd of zebras eat grass in a grassy plain in the middle of a grassy plain
# cap:statues of two people riding bicycles
# cap:some people with snowboards on the snow
# cap:A man is throwing a frisbee to the other man
# cap:green and white bus at the curb parked in front of a building
# cap:polar bear eats a carrot and blue bag
# cap:the bus stops
# cap:sitting and sitting next to a pond
# cap:a building with a clock on top
# negetive node_word:clock
# cap:a building with a sign and a street sign
# cap:a black metal table with an open umbrella on the patio
# cap:a small boat with two people out on the water
# cap:a passenger airplane in a stormy day
# negetive node_word:person
# cap:street signs and street signs are on a pole in the sky
# cap:Two people and two horses going on a sandy beach
# cap:near tall buildings
# cap:child and woman looking at a bear at bear habitat
# negetive node_word:person
# negetive node_word:person
# cap:man in the park flying while on his feet
# cap:a cluttered desk with books, papers and computer monitor.
# SPICE	METEOR	CIDEr	CHAIRs	CHAIRi
# 0.0	0.0	0.0	30.3	28.2

# %%
# Out:
# 100%|██████████| 100/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1886.78it/s]
# gt_objects:{'tv', 'ottoman', 'quilt', 'mirror', 'couch', 'wall', 'pillow', 'lamp', 'room', 'bed', 'curtain'}
# cap:i like the white
# gt_objects:{'leg', 'wall', 'feather', 'grass', 'head', 'shadow', 'gun_muzzle', 'animal', 'neck', 'eating', 'log', 'nose', 'trunk', 'bird', 'land', 'fur'}
# cap:of the ostrich eating
# gt_objects:set()
# cap:a black fence
# gt_objects:{'coconut_milk', 'handle', 'pretzel', 'noodle', 'meat', 'compartment', 'utensil', 'gravy', 'dining table', 'corn', 'metallic_element', 'tortilla', 'vegetable', 'dish', 'bowl', 'food', 'rice', 'part'}
# cap:the plate is silver
# gt_objects:{'railing', 'gravestone', 'cemetery', 'grass', 'building', 'house', 'roof', 'sky', 'bench', 'post', 'window', 'cross', 'chimney'}
# cap:sky
# gt_objects:{'tree', 'sidewalk', 'plaque', 'traffic_light', 'cable', 'building', 'car', 'sign', 'street', 'sky', 'traffic light', 'pole', 'tire', 'light', 'cloud'}
# cap:i see a stop light and a street sign near some trees
# gt_objects:{'water', 'boat', 'fence', 'sign', 'dock', 'sky', 'flag', 'person', 'barrier', 'pole', 'rock'}
# cap:two wooden posts
# gt_objects:{'decoration', 'shirt', 'sidewalk', 'building', 'tattoo', 'door', 'hand', 'curb', 'cart', 'brick', 'shoe', 'skateboard', 'person', 'short_pants', 'wheel', 'window'}
# cap:The skate boarder is riding his skate board in mid-air
# gt_objects:{'shirt', 'male_child', 'hinge', 'wall', 'baseboard', 'hair', 'rug', 'floor', 'door', 'doorstop', 'painting', 'trouser', 'factory', 'necktie', 'mercantile_establishment', 'doorknob'}
# cap:boy is wearing a tie
# negetive node_word:person
# negetive word:boy
# negetive node_word:tie
# negetive word:tie
# gt_objects:{'shirt', 'hat', 'shoe', 'internet', 'umpire', 'tennis_racket', 'ladder', 'person', 'short_pants', 'sports ball', 'gate', 'official', 'partition'}
# cap:tennis players on tennis court with fans watching
# gt_objects:{'basketball_player', 'line', 'basketball', 'numeral', 'sleeve', 'internet', 'court', 'gym_shoe', 'hair', 'person', 'new_jersey', 'crowd', 'letter'}
# cap:Three basketball players are playing an exhibition game
# gt_objects:set()
# cap:people walking
# negetive node_word:person
# negetive word:person
# gt_objects:{'coat', 'tree', 'shirt', 'hand', 'neck', 'water', 'button', 'head', 'hair', 'bear', 'person', 'hill', 'ear', 'chin'}
# cap:two people stand by a boat next to a river
# negetive node_word:boat
# negetive word:boat
# gt_objects:{'decoration', 'tree', 'blind', 'fabric', 'wall', 'blanket', 'pillow', 'vase', 'shadow', 'bed', 'flower', 'design', 'chimney', 'pane', 'house', 'frame', 'window', 'curtain'}
# cap:the room has curtains
# gt_objects:{'airplane', 'engine', 'gear', 'picture', 'tail', 'sky', 'wheel', 'cockpit', 'cloud', 'wing'}
# cap:airplane in the sky, with landing apron
# gt_objects:{'tree', 'headlight', 'eye', 'motorcycle', 'head', 'hair', 'road', 'shadow', 'ear', 'mustache', 'helmet', 'shoe', 'trouser', 'shrub', 'sky', 'land', 'jacket', 'person', 'wheel', 'mouth'}
# cap:a man on a motorcycle
# gt_objects:set()
# cap:A tennis player is in the air, swinging the racket
# negetive node_word:person
# negetive word:player
# negetive node_word:tennis racket
# negetive word:racket
# gt_objects:{'coat', 'tree', 'ski_pole', 'shade', 'skis', 'snow', 'shadow', 'slope', 'hand', 'trouser', 'footprint', 'sky', 'person', 'trail', 'hill', 'cloud'}
# cap:person is skiing down a snowy trail
# gt_objects:{'shirt', 'line', 'hillside', 'skateboarding', 'sock', 'street', 'road', 'rock', 'helmet', 'curb', 'shoe', 'skateboard', 'cone', 'land', 'flag', 'person', 'short_pants', 'wheel'}
# cap:a skateboarder on a skateboard
# gt_objects:{'shirt', 'hand', 'helium', 'tennis racket', 'hair', 'camera', 'logo', 'person', 'headband', 'smile', 'set'}
# cap:person is a tennis player
# gt_objects:{'shirt', 'coffee', 'potato', 'fork', 'chump', 'syrup', 'panel', 'arm', 'hair', 'ponytail', 'couple', 'bag', 'design', 'bacon', 'catsup', 'bottle', 'dining table', 'cell phone', 'cup', 'chair', 'dish', 'bowl', 'milk', 'food', 'person', 'short_pants', 'plate', 'word', 'cake'}
# cap:of a man and woman smiling together
# gt_objects:set()
# cap:people are wearing red
# negetive node_word:person
# negetive word:person
# gt_objects:{'shirt', 'glove', 'tree', 'hand', 'trunk', 'sunglasses', 'sky', 'person', 'snowboard', 'hill', 'snow', 'trail', 'leaf', 'face', 'topographic_point'}
# cap:a man snarling in the snow on a snowboard
# gt_objects:{'sidewalk', 'railing', 'background', 'skateboarding', 'skateboard', 'step', 'arm', 'concrete', 'sky', 'land', 'person', 'pole', 'shadow', 'ramp', 'cloud'}
# cap:person is on a skateboard
# gt_objects:{'shirt', 'knot', 'eye', 'finger', 'wall', 'eyebrow', 'arm', 'head', 'hair', 'spectacles', 'ear', 'piece', 'thumb', 'face', 'tendon', 'mustache', 'hand', 'lip', 'necktie', 'person', 'wrist'}
# cap:man is wearing a black shirt
# gt_objects:{'shirt', 'sock', 'hair', 'stadium', 'area', 'camera', 'spectacles', 'shoe', 'trouser', 'chair', 'tennis racket', 'internet', 'tennis_court', 'person', 'short_pants', 'wrist', 'sports ball', 'tennis_player'}
# cap:Man with tennis racquet
# gt_objects:{'boat', 'building', 'horizon', 'dock', 'sky', 'post', 'pole', 'ripple', 'light', 'window', 'cloud'}
# cap:two boats are moored on the pier
# gt_objects:{'tree', 'leg', 'doorway', 'blouse', 'hair', 'shade', 'customer', 'radio_beam', 'case', 'shaker', 'utensil', 'dining table', 'ceiling', 'chair', 'holder', 'bowl', 'bench', 'food', 'land', 'jacket', 'person', 'menu', 'restaurant'}
# cap:people sitting at tables
# gt_objects:{'potato', 'paper_plate', 'form', 'base', 'abrasion', 'blade', 'counter', 'banana', 'blender', 'glass'}
# cap:the bananas are not all touching in the photo
# gt_objects:set()
# cap:The plane is flying up and in the air
# negetive node_word:airplane
# negetive word:plane
# gt_objects:{'shirt', 'eye', 'finger', 'fence', 'eyebrow', 'hair', 'ear', 'face', 'hand', 'fingernail', 'nose', 'umbrella', 'food', 'person', 'tooth', 'mouth'}
# cap:man sitting outside eating a hotdog
# gt_objects:{'tree', 'sign', 'fence', 'pole'}
# cap:bare trees
# gt_objects:{'rope', 'shirt', 'water', 'wall', 'boat', 'building', 'bench', 'person', 'short_pants', 'leaf'}
# cap:people on board a boat
# gt_objects:{'shirt', 'bedroom', 'wall', 'form', 'building', 'hair', 'shade', 'box', 'headboard', 'room', 'rug', 'bed', 'door', 'painting', 'booklet', 'couch', 'chair', 'picture', 'person', 'frame', 'lamp', 'window', 'tissue', 'curtain', 'coffee_table'}
# cap:a living room with rugs, couches, and chairs
# gt_objects:{'shirt', 'sand', 'sunglasses', 'hair', 'ponytail', 'surfboard', 'beach', 'shoe', 'section', 'wave', 'ocean', 'person', 'short_pants', 'swimsuit', 'foam', 'bikini'}
# cap:a pink surf board
# gt_objects:{'plug', 'slide_fastener', 'switch', 'wire', 'wall', 'land', 'knob', 'mercantile_establishment', 'bag', 'sweater', 'jean', 'door', 'strap'}
# cap:a man sits on a red bag
# negetive node_word:person
# negetive word:man
# gt_objects:{'paw', 'leg', 'collar', 'eye', 'corner', 'button', 'car', 'head', 'tongue', 'ear', 'face', 'parking_lot', 'name', 'nose', 'chair', 'harness', 'fur', 'dog', 'leash', 'window', 'mouth', 'strap'}
# cap:a dog inside a car
# gt_objects:{'shirt', 'line', 'male_child', 'sock', 'court', 'gym_shoe', 'hair', 'sunglasses', 'pole', 'tennis', 'gesture', 'set', 'hand', 'shoe', 'tennis racket', 'land', 'flag', 'person', 'short_pants', 'wrist', 'symbol'}
# cap:man is in action
# gt_objects:{'shirt', 'line', 'handle', 'male_child', 'building', 'fence', 'court', 'tarpaulin', 'cap', 'elbow', 'material', 'tennis racket', 'banner', 'sign', 'sports ball', 'short_pants', 'word', 'air'}
# cap:boy standing in a tennis court
# negetive node_word:person
# negetive word:boy
# gt_objects:{'tv', 'wall', 'shade', 'rug', 'plant', 'figurine', 'floor', 'dining table', 'ceiling', 'couch', 'chair', 'fireplace', 'house', 'picture', 'tartan', 'lamp', 'window'}
# cap:the room is bright with white walls with tan furniture
# gt_objects:{'tv', 'wall', 'building', 'car', 'hour_hand', 'band', 'light', 'letter', 'ad', 'pavement', 'shop', 'hand', 'sign', 'sky', 'flag', 'scene', 'clock', 'hole'}
# cap:car driving at night
# gt_objects:{'duct_tape', 'person', 'inscription', 'surfboard', 'cloud', 'wave', 'sky'}
# cap:guy is on the surfboard
# gt_objects:{'decoration', 'beach', 'kite', 'water', 'decal', 'wave', 'sky', 'interruption', 'ocean', 'structure', 'island', 'cloud', 'figure'}
# cap:several people are parasailing in the open ocean in a beautiful day
# negetive node_word:person
# negetive word:person
# gt_objects:{'bicycle', 'car', 'sign', 'post', 'road', 'shadow', 'truck', 'window', 'writing'}
# cap:cars driving along a highway
# gt_objects:{'paw', 'leg', 'back', 'grass', 'street', 'car', 'head', 'shadow', 'light', 'ear', 'pavement', 'nose', 'foot', 'tail', 'land', 'fur', 'dog', 'wheel', 'tire'}
# cap:a dog walking on the road near a car
# gt_objects:{'toothbrush', 'square', 'toiletry', 'wall', 'window', 'dish', 'bathtub', 'shower_curtain', 'light', 'glass', 'sink', 'soap'}
# cap:there is a toilet and bathtub
# negetive node_word:toilet
# negetive word:toilet
# gt_objects:{'dining table', 'broccoli', 'meat', 'wine', 'food', 'plate', 'glass'}
# cap:a steak on a plate
# gt_objects:{'shirt', 'dining table', 'neck', 'fork', 'cell phone', 'finger', 'wall', 'chair', 'hair', 'bowl', 'food', 'lanyard', 'person', 'napkin', 'spectacles'}
# cap:a person is eating while talking on a phone
# gt_objects:{'tree', 'animal', 'leg', 'trunk', 'brick', 'wall', 'grass', 'fence', 'hair', 'land', 'menagerie', 'rock'}
# cap:Several elephants in a pen
# negetive node_word:elephant
# negetive word:elephant
# gt_objects:{'dais', 'hat', 'trouser', 'banner', 'jacket', 'person', 'three', 'rug', 'one'}
# cap:three people standing on podiums
# gt_objects:{'shirt', 'wall', 'vent', 'gym_shoe', 'backpack', 'circle', 'hair', 'rubbish', 'rug', 'band', 'letter', 'floor', 'hand', 'fingernail', 'cell phone', 'trouser', 'chair', 'cone', 'display', 'contemplation', 'base', 'person', 'wheel', 'clock_face'}
# cap:samsung sgs7
# gt_objects:{'dining table', 'tv', 'chump', 'cell phone', 'wall', 'earphone', 'fan', 'picture'}
# cap:desks
# gt_objects:set()
# cap:bathroom sinks
# negetive node_word:sink
# negetive word:sink
# gt_objects:{'eye', 'cup', 'head', 'person', 'bear', 'love', 'letter', 'face', 'ribbon'}
# cap:a teddy bear
# gt_objects:{'shirt', 'tv', 'wall', 'collage', 'sunlight', 'tower', 'room', 'rug', 'spectacles', 'body', 'floor', 'door', 'dining table', 'trouser', 'couch', 'picture', 'person', 'window'}
# cap:young people sitting in a living room with a a computer
# negetive node_word:laptop
# negetive word:computer
# gt_objects:{'shirt', 'tree', 'sidewalk', 'leg', 'finger', 'background', 'object', 'car', 'arm', 'drain', 'head', 'lace', 'photograph', 'bus', 'face', 'elbow', 'hand', 'nose', 'foot', 'shoe', 'jean', 'skateboard', 'person', 'wheel', 'air'}
# cap:man is on skateboard
# gt_objects:{'tree', 'line', 'leg', 'boundary_line', 'fence', 'court', 'goal', 'sweatshirt', 'tennis_racket', 'hair', 'pole', 'shadow', 'hand', 'heel', 'helmet', 'shoe', 'foot', 'trouser', 'text', 'string', 'tennis_court', 'land', 'person', 'short_pants', 'field', 'inscription', 'sports ball', 'tennis_ball'}
# cap:tennis player on the tennis court
# gt_objects:{'shirt', 'leg', 'branch', 'wall', 'arm', 'rubbish', 'counter', 'bag', 'countertop', 'tank_top', 'hand', 'calendar', 'root', 'cement', 'chair', 'shelf', 'land', 'person', 'banana', 'platform', 'basket', 'bunch'}
# cap:a man is preparing bananas, he is near a market
# gt_objects:{'photograph', 'person', 'shadow', 'word', 'new_jersey'}
# cap:a bunch of players seated on some grassy area, with a team photo in the background
# gt_objects:{'bathroom', 'plug', 'tile', 'plaything', 'cup', 'object', 'chair', 'book', 'lacrimation', 'bathtub', 'lever', 'mat', 'toilet', 'floor', 'soap'}
# cap:a baby bathtub is on a tv stand
# negetive node_word:tv
# negetive word:tv
# negetive node_word:person
# negetive word:baby
# gt_objects:{'leg', 'pomegranate', 'bin', 'noodle', 'face', 'ranch', 'pea', 'spider', 'sign', 'vegetable', 'ghost', 'bowl', 'cauliflower', 'dog', 'napkin', 'cracker'}
# cap:the food is pumpkin
# gt_objects:{'spectator', 'line', 'handle', 'wall', 'nike', 'court', 'gym_shoe', 'sunglasses', 'ponytail', 'guard', 'hat', 'face', 'tank_top', 'shoe', 'tennis racket', 'tennis_court', 'base', 'person', 'short_pants', 'visor'}
# cap:a woman is holding a tennis racquet
# gt_objects:{'shirt', 'line', 'scarf', 'eye', 'wall', 'arm', 'head', 'bear', 'ear', 'face', 'ribbon', 'foot', 'universal', 'shelf', 'land', 'inscription', 'surface'}
# cap:there are four teddy bears
# gt_objects:set()
# cap:giraffe eating from a tree atop a fence
# negetive node_word:giraffe
# negetive word:giraffe
# gt_objects:{'leg', 'male_child', 'grass', 'soil', 'sock', 'pitch', 'road', 'band', 'edge', 'shadow', 'pavement', 'design', 'sole', 'hand', 'crack', 'shoe', 'weed', 'skateboard', 'land', 'person', 'wheel', 'part', 'air'}
# cap:person is skating
# gt_objects:set()
# cap:white toilet seat
# negetive node_word:toilet
# negetive word:toilet
# negetive node_word:chair
# negetive word:seat
# gt_objects:{'decoration', 'guitar', 'bud', 'dining table', 'wall', 'art', 'picture', 'vase', 'pot', 'candle', 'daisy', 'flower', 'coaster'}
# cap:flowers in a vase on a glass table
# gt_objects:{'shirt', 'shoe', 'cell phone', 'trouser', 'male_child', 'skateboard', 'watchband', 'person', 'ramp'}
# cap:two men in blue shirts
# gt_objects:{'flavorer', 'band', 'knot', 'oat', 'metallic_element', 'dining table', 'pie', 'wood', 'seed', 'rotter', 'bowl', 'plate', 'rim', 'spoon', 'topographic_point'}
# cap:i
# gt_objects:{'eye', 'trunk', 'ivory', 'background', 'skin', 'elephant', 'ear', 'rock', 'face'}
# cap:two elephants with trunks touching
# gt_objects:{'glove', 'pine', 'building', 'backpack', 'pole', 'snow', 'shadow', 'slope', 'rock', 'cap', 'trouser', 'sky', 'land', 'jacket', 'person', 'path', 'mountain'}
# cap:person on skiing on a snow covered hill
# gt_objects:{'knee', 'board', 'water', 'building', 'wave', 'hair', 'sky', 'land', 'logo', 'person', 'aftermath', 'surfboard', 'cloud'}
# cap:person is wearing a wetsuit with a bright blue top
# gt_objects:{'landing_gear', 'tree', 'nose', 'airplane', 'background', 'tail', 'sky', 'wheel', 'propeller', 'snow', 'window', 'mountain', 'wing'}
# cap:plane is black and white and has red stripes on white
# gt_objects:set()
# cap:bicycles in a row
# negetive node_word:bicycle
# negetive word:bicycle
# gt_objects:set()
# cap:boy is lying down laying in bed
# negetive node_word:person
# negetive word:boy
# negetive node_word:bed
# negetive word:bed
# gt_objects:{'tree', 'animal', 'neck', 'leg', 'root', 'grass', 'house', 'fence', 'head', 'area', 'field', 'antler', 'deer', 'window', 'rock'}
# cap:the scene
# gt_objects:{'tree', 'fence', 'court', 'head', 'shed', 'shadow', 'tennis', 'design', 'cap', 'shoe', 'foot', 'pocket', 'tennis racket', 'land', 'person', 'short_pants', 'frame', 'sports ball', 'writing'}
# cap:man wearing blue and white shirt
# gt_objects:{'dining table', 'tv', 'screen', 'keyboard', 'laptop', 'rack', 'shelf', 'image', 'remote_control', 'key', 'spectacles', 'light', 'glass', 'medium'}
# cap:people watching television
# negetive node_word:person
# negetive word:person
# gt_objects:{'tree', 'scarf', 'grass', 'saddle', 'sheep', 'road', 'hat', 'herd', 'horse', 'trouser', 'person', 'distance', 'field', 'hill', 'mountain', 'boot'}
# cap:The man is walking along the road
# gt_objects:{'shirt', 'line', 'building', 'airdock', 'pole', 'star', 'door', 'group', 'airplane', 'uniform', 'chair', 'sign', 'flag', 'person', 'propeller', 'pillar', 'window', 'boot'}
# cap:a group of soldiers stand around an airplane
# gt_objects:{'bus', 'bicycle', 'window', 'street', 'cloud', 'traffic light', 'sky'}
# cap:two buses are moving down the street
# gt_objects:{'metallic_element', 'wall', 'sign', 'bag', 'stud', 'roller', 'pipe', 'donut', 'distance', 'writing', 'conveyer_belt', 'tube', 'axial_rotation'}
# cap:machine is making doughnuts
# gt_objects:{'refrigerator', 'kitchen', 'wall', 'building', 'stack', 'book', 'oven', 'counter', 'light', 'bookshelf', 'dining table', 'microwave', 'cell phone', 'chair', 'picture', 'shelf', 'person', 'coffee_maker'}
# cap:the apartment's kitchen includes black and brown wood floors
# gt_objects:{'necklace', 'watch', 'form', 'hair', 'circle', 'hairpin', 'ribbon', 'cellular_telephone', 'hand', 'shoe', 'foot', 'belt', 'tie', 'land', 'watchband', 'person', 'wrist', 'pillar', 'dress', 'air'}
# cap:woman in dress holding cell phone
# negetive node_word:cell phone
# negetive word:phone
# gt_objects:{'handle', 'blind', 'fabric', 'back', 'sand', 'appetizer', 'pizza', 'shell', 'spatula', 'bottle', 'dining table', 'scissors', 'chair', 'tomato', 'gummed_label', 'land', 'candle', 'plate', 'window', 'pastry', 'jar'}
# cap:two plates of pizza
# gt_objects:{'tree', 'park', 'shrub', 'grass', 'fence', 'bird', 'flower', 'bench', 'leaf', 'rock'}
# cap:the duck is moving very slowly, but is walking
# gt_objects:{'hillside', 'tag', 'grass', 'head', 'plant_part', 'ear', 'plant', 'neck', 'wire', 'weed', 'shrub', 'sky', 'land', 'field', 'leaf', 'mountain', 'cloud', 'cow'}
# cap:several cows stand near a barbed wire fence
# gt_objects:{'beard', 'rope', 'spectacle', 'costume', 'fur_hat', 'trim', 'robe', 'fur', 'sports ball', 'ear'}
# cap:man is wearing santa claus
# negetive node_word:person
# negetive word:man
# gt_objects:{'dining table', 'water', 'beak', 'dixie_cup', 'bird', 'food', 'napkin', 'plate', 'accent', 'glass', 'pastry', 'design'}
# cap:birds
# gt_objects:{'doorway', 'towel', 'mirror', 'wall', 'arm', 'head', 'camera', 'sunlight', 'edge', 'flower', 'hand', 'stairway', 'wallpaper', 'land', 'person', 'mercantile_establishment', 'window', 'bannister'}
# cap:the reflection is blue
# gt_objects:{'shirt', 'barroom', 'catcher', 'line', 'surface', 'ball_field', 'baseball', 'bat', 'grass', 'soil', 'poster', 'pen', 'crowd', 'ingot', 'home_plate', 'helmet', 'railing', 'uniform', 'numeral', 'trouser', 'sign', 'umpire', 'base', 'dugout', 'person', 'batter', 'field', 'clay'}
# cap:a baseball batter hitting a home plate
# gt_objects:{'tree', 'pilot', 'grass', 'exhaust', 'hanger', 'pylon', 'nozzle', 'wing', 'landing_gear', 'nose', 'engine', 'airplane', 'numeral', 'tail', 'track', 'sky', 'logo', 'flag', 'wheel', 'cockpit', 'cross'}
# cap:the sky is blue
# gt_objects:{'tree', 'room', 'numeral', 'sign', 'roof', 'land', 'pole', 'clock', 'pillar', 'window', 'topographic_point'}
# cap:clock on the roof
# gt_objects:{'moss', 'water', 'waterfall', 'shrub', 'hair', 'person', 'short_pants', 'bikini', 'plant', 'rock'}
# cap:woman kneeling in front of waterfall
# gt_objects:{'tree', 'garage', 'wall', 'car', 'fence', 'balcony', 'planter', 'row_house', 'road', 'door', 'driveway', 'support', 'apartment', 'house', 'sign', 'column', 'window'}
# cap:the car is white
# gt_objects:{'tree', 'tag', 'branch', 'nose', 'grass', 'mouth', 'sunlight', 'shadow', 'ear', 'leaf', 'abdomen', 'face', 'cow'}
# cap:- the cow is white and has black spots
# gt_objects:{'shirt', 'barroom', 'tv', 'blouse', 'picture', 'brow', 'hair', 'mouth', 'tongue', 'person', 'part', 'bottle', 'cap'}
# cap:woman holding beer in hand
# gt_objects:{'color', 'grass', 'row', 'window', 'side', 'post', 'pole', 'tarmacadam', 'snow', 'vehicle', 'dawn', 'plant', 'door', 'wing', 'tip', 'railing', 'airplane', 'engine', 'tail', 'track', 'sky', 'bench', 'logo', 'airline', 'truck', 'inscription', 'part', 'writing'}
# cap:The airliners tarmac is paved with snow
# gt_objects:{'shop', 'headlight', 'face', 'building', 'drift', 'sign', 'car', 'window', 'pole', 'writing', 'clock', 'bus', 'awning', 'door'}
# cap:street lights on side of street
# gt_objects:{'dining table', 'crust', 'fork', 'handle', 'frost', 'tine', 'contemplation', 'air_pocket', 'edge', 'plate', 'light', 'cake', 'prong'}
# cap:square dessert plate
# SPICE	METEOR	CIDEr	CHAIRs	CHAIRi
# 0.0	0.0	0.0	21.0	25.2
